# %%
"""
Reinforcement learning maze example.
Red rectangle:          explorer.
Black rectangles:       hells       [reward = -1].
Yellow bin circle:      paradise    [reward = +1].
All other states:       ground      [reward = 0].
This script is the main part which controls the update method of this example.
The RL is in RL_brain.py.
View more on my tutorial page: https://morvanzhou.github.io/tutorials/
"""

from maze_env import Maze
from RL_brain import QLearningTable


# Q-learning
def update():
    for episode in range(100):
        # initial observation
        observation = env.reset()

        while True:
            # fresh env
            env.render()

            # RL choose action based on observation
            action = RL.choose_action(str(observation))

            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)

            # RL learn from this transition
            RL.learn(str(observation), action, reward, str(observation_))

            # swap observation
            observation = observation_

            # break while loop when end of this episode
            if done:
                break

    # end of game
    print('game over')
    env.destroy()

if __name__ == "__main__":
    
    env = Maze()
    # actions = [0, 1, 2, 3]
    RL = QLearningTable(actions=list(range(env.n_actions)))
    print(RL.q_table)
    env.after(100, update)
    env.mainloop()
    print(RL.q_table)
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []
# game over
#                                          0             1             2  \
# [5.0, 5.0, 35.0, 35.0]        6.335149e-08  1.620037e-04  4.705710e-13
# [45.0, 5.0, 75.0, 35.0]       0.000000e+00  4.971425e-08  0.000000e+00
# [85.0, 5.0, 115.0, 35.0]      0.000000e+00 -2.970100e-02  0.000000e+00
# terminal                      0.000000e+00  0.000000e+00  0.000000e+00
# [125.0, 5.0, 155.0, 35.0]     0.000000e+00  0.000000e+00  0.000000e+00
# [125.0, 45.0, 155.0, 75.0]    0.000000e+00  0.000000e+00  0.000000e+00
# [5.0, 45.0, 35.0, 75.0]       1.554679e-06  1.308957e-03  1.705957e-08
# [5.0, 85.0, 35.0, 115.0]      7.920023e-06  8.559457e-03 -5.851985e-02
# [45.0, 45.0, 75.0, 75.0]      0.000000e+00 -1.990000e-02 -1.000000e-02
# [125.0, 85.0, 155.0, 115.0]   0.000000e+00  0.000000e+00  0.000000e+00
# [125.0, 125.0, 155.0, 155.0]  0.000000e+00  0.000000e+00  0.000000e+00
# [85.0, 125.0, 115.0, 155.0]   5.701110e-01  4.807957e-03  0.000000e+00
# [5.0, 125.0, 35.0, 155.0]     1.412492e-07  4.462879e-06  4.814835e-02
# [45.0, 125.0, 75.0, 155.0]   -2.970100e-02  2.264137e-03  1.927169e-01
#
#                                          3
# [5.0, 5.0, 35.0, 35.0]        3.590425e-07
# [45.0, 5.0, 75.0, 35.0]       0.000000e+00
# [85.0, 5.0, 115.0, 35.0]      0.000000e+00
# terminal                      0.000000e+00
# [125.0, 5.0, 155.0, 35.0]     0.000000e+00
# [125.0, 45.0, 155.0, 75.0]   -1.000000e-02
# [5.0, 45.0, 35.0, 75.0]       7.253580e-07
# [5.0, 85.0, 35.0, 115.0]      2.570087e-07
# [45.0, 45.0, 75.0, 75.0]      1.515654e-05
# [125.0, 85.0, 155.0, 115.0]   0.000000e+00
# [125.0, 125.0, 155.0, 155.0]  0.000000e+00
# [85.0, 125.0, 115.0, 155.0]   3.220094e-03
# [5.0, 125.0, 35.0, 155.0]     6.515125e-05
# [45.0, 125.0, 75.0, 155.0]    5.201752e-04
