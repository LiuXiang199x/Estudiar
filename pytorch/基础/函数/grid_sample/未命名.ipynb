# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
inputs = torch.randn(1,4,480,480)
crop_grid = torch.randn(1, 240, 240, 2)
output = F.grid_sample(inputs, crop_grid, mode="bilinear")
print(inputs[:][0][:5][:5])
# Out:
# tensor([[[-0.7440, -1.5076,  0.8235,  ...,  0.8397, -0.0431,  1.2412],
#          [-1.1644, -0.3010, -0.6336,  ..., -0.5113, -0.9523,  0.4272],
#          [ 2.0460, -0.6919, -0.6409,  ..., -0.1111, -0.6369, -2.1282],
#          ...,
#          [-0.7292, -0.2188,  0.1344,  ...,  1.0157,  0.2821, -0.3366],
#          [-0.4373, -1.4256,  2.3825,  ..., -1.9220,  0.3003, -2.3064],
#          [-1.6754,  1.3705, -1.5111,  ..., -1.5986,  0.5141, -0.1371]],
#
#         [[-1.0638, -0.0926, -0.7618,  ...,  0.1541, -0.0396, -1.3246],
#          [-0.0318,  2.2469,  0.2057,  ...,  0.0743,  1.1892, -0.5723],
#          [-0.8750,  0.0320,  0.9499,  ..., -0.7663,  0.2908, -0.9643],
#          ...,
#          [-1.1780, -0.0489, -0.0895,  ...,  1.7315,  1.0378, -0.2578],
#          [ 0.4383,  0.4929,  0.4672,  ..., -0.6335,  0.0469, -0.8176],
#          [-1.5421,  0.6574, -0.1331,  ..., -0.8652,  0.1041,  0.6914]],
#
#         [[-2.8586,  0.1543,  0.2115,  ...,  0.7961,  1.1846, -0.1673],
# ...

# %%
print(output[:][0][:5][:5])
# Out:
# tensor([[[ 0.8086,  0.0000,  0.0768,  ...,  0.0000, -0.4802,  0.0000],
#          [ 0.0000,  0.4272,  0.0000,  ..., -0.5014,  1.3949,  0.0000],
#          [ 0.2200,  0.0000, -0.7332,  ...,  0.0000,  0.0000,  0.1738],
#          ...,
#          [ 0.5331,  0.0000,  1.4355,  ..., -0.7010,  0.0000, -0.6970],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0963],
#          [ 0.0000, -0.9683,  0.0000,  ..., -0.5552, -0.6589, -0.1522]],
#
#         [[ 0.4170,  0.0000, -0.2938,  ...,  0.0000, -0.0987,  0.0000],
#          [ 0.0000, -0.3579,  0.0000,  ..., -0.6537,  1.4678,  0.0000],
#          [ 0.0021,  0.0000, -1.6037,  ...,  0.0000,  0.0000,  0.5246],
#          ...,
#          [-0.7528,  0.0000, -0.2612,  ...,  0.1515,  0.0000, -0.0032],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  1.1711],
#          [ 0.0000, -0.4655,  0.0000,  ..., -0.5086, -0.1510,  0.3598]],
#
#         [[ 0.0041,  0.0000, -0.1380,  ...,  0.0000, -0.1750,  0.0000],
# ...
