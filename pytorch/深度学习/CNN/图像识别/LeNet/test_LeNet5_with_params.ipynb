# %%
import torch
import torchvision
from torchvision import datasets,transforms
import matplotlib.pyplot as plt
import numpy as np
import cv2
 
import torch.nn as nn
import torch.nn.functional as F

import tensorboard

model_path = "Lenet5_1000.pth"

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
 
transform = transforms.Compose([
        transforms.ToTensor(), # 转为Tensor
        transforms.Normalize((0.5,), (0.5,)), # 归一化
                             ])
 
train_dataset = torchvision.datasets.MNIST(root='./mnist', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.MNIST(root='./mnist', train=False, transform=transform, download=True)
 
batch_size = 4
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

 
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5, padding=2)
        self.conv2 = nn.Conv2d(6, 16, 5)  
        self.fc1   = nn.Linear(16*5*5, 120)  
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)
 
    def forward(self, x): 
        # print(x.size())    # 4-1-28-28
        
        x = F.max_pool2d(F.relu(self.conv1(x)), (2,2)) 
        # print(x.size())    # # 4-6-14-14
        
        x = F.max_pool2d(F.relu(self.conv2(x)), (2,2))
        # print("x.size():", x.size())   # 4-16-5-5
        
        x = x.view(x.size()[0], -1)   #展开成一维的
        # print("x.size():", x.size())   # 4-400
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)        
        return x
net = Net()
net.load_state_dict(torch.load(model_path))
# print(list(net.parameters()))
# Out:
# <All keys matched successfully>

# %%
torch.save(net, "allnet.pth")
# Out:
# /home/xiang/anaconda3/envs/py37/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
#整个测试集上预测
correct = 0
total = 0
 
with torch.no_grad():
    for (images,labels) in testloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs,1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum()

        print('10000张测试集合中的准确率为：', (correct.cpu().numpy()/total * 100))
print(correct)
# Out:
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 100.0
# 10000张测试集合中的准确率为： 99.13793103448276
# 10000张测试集合中的准确率为： 99.16666666666667
# 10000张测试集合中的准确率为： 99.19354838709677
# 10000张测试集合中的准确率为： 99.21875
# 10000张测试集合中的准确率为： 99.24242424242425
# 10000张测试集合中的准确率为： 99.26470588235294
# 10000张测试集合中的准确率为： 99.28571428571429
# 10000张测试集合中的准确率为： 99.30555555555556
# 10000张测试集合中的准确率为： 99.32432432432432
# 10000张测试集合中的准确率为： 99.3421052631579
# 10000张测试集合中的准确率为： 99.35897435897436
# 10000张测试集合中的准确率为： 99.375
# 10000张测试集合中的准确率为： 99.39024390243902
# 10000张测试集合中的准确率为： 99.40476190476191
# 10000张测试集合中的准确率为： 99.4186046511628
# 10000张测试集合中的准确率为： 99.43181818181817
# 10000张测试集合中的准确率为： 99.44444444444444
# 10000张测试集合中的准确率为： 99.45652173913044
# 10000张测试集合中的准确率为： 99.46808510638297
# 10000张测试集合中的准确率为： 99.47916666666666
# 10000张测试集合中的准确率为： 99.48979591836735
# 10000张测试集合中的准确率为： 99.5
# 10000张测试集合中的准确率为： 99.50980392156863
# 10000张测试集合中的准确率为： 99.51923076923077
# 10000张测试集合中的准确率为： 99.52830188679245
# 10000张测试集合中的准确率为： 99.53703703703704
# 10000张测试集合中的准确率为： 99.54545454545455
# 10000张测试集合中的准确率为： 99.55357142857143
# 10000张测试集合中的准确率为： 99.56140350877193
# 10000张测试集合中的准确率为： 99.56896551724138
# 10000张测试集合中的准确率为： 99.57627118644068
# 10000张测试集合中的准确率为： 99.58333333333333
# 10000张测试集合中的准确率为： 99.59016393442623
# 10000张测试集合中的准确率为： 99.19354838709677
# 10000张测试集合中的准确率为： 99.20634920634922
# 10000张测试集合中的准确率为： 99.21875
# 10000张测试集合中的准确率为： 99.23076923076923
# 10000张测试集合中的准确率为： 99.24242424242425
# 10000张测试集合中的准确率为： 99.25373134328358
# 10000张测试集合中的准确率为： 99.26470588235294
# 10000张测试集合中的准确率为： 99.27536231884058
# 10000张测试集合中的准确率为： 99.28571428571429
# 10000张测试集合中的准确率为： 99.29577464788733
# 10000张测试集合中的准确率为： 99.30555555555556
# 10000张测试集合中的准确率为： 99.31506849315068
# 10000张测试集合中的准确率为： 99.32432432432432
# 10000张测试集合中的准确率为： 99.33333333333333
# 10000张测试集合中的准确率为： 99.3421052631579
# 10000张测试集合中的准确率为： 99.35064935064936
# 10000张测试集合中的准确率为： 99.35897435897436
# 10000张测试集合中的准确率为： 99.36708860759494
# 10000张测试集合中的准确率为： 99.375
# 10000张测试集合中的准确率为： 99.38271604938271
# 10000张测试集合中的准确率为： 99.39024390243902
# 10000张测试集合中的准确率为： 99.3975903614458
# 10000张测试集合中的准确率为： 99.40476190476191
# 10000张测试集合中的准确率为： 99.41176470588235
# 10000张测试集合中的准确率为： 99.4186046511628
# 10000张测试集合中的准确率为： 99.42528735632183
# 10000张测试集合中的准确率为： 99.43181818181817
# 10000张测试集合中的准确率为： 99.43820224719101
# 10000张测试集合中的准确率为： 99.16666666666667
# 10000张测试集合中的准确率为： 99.17582417582418
# 10000张测试集合中的准确率为： 99.18478260869566
# 10000张测试集合中的准确率为： 99.19354838709677
# 10000张测试集合中的准确率为： 99.20212765957447
# 10000张测试集合中的准确率为： 99.21052631578947
# 10000张测试集合中的准确率为： 99.21875
# 10000张测试集合中的准确率为： 99.22680412371135
# 10000张测试集合中的准确率为： 99.23469387755102
# 10000张测试集合中的准确率为： 99.24242424242425
# 10000张测试集合中的准确率为： 99.25
# 10000张测试集合中的准确率为： 99.25742574257426
# 10000张测试集合中的准确率为： 99.26470588235294
# 10000张测试集合中的准确率为： 99.27184466019418
# 10000张测试集合中的准确率为： 99.03846153846155
# 10000张测试集合中的准确率为： 99.04761904761905
# 10000张测试集合中的准确率为： 99.05660377358491
# 10000张测试集合中的准确率为： 99.06542056074767
# 10000张测试集合中的准确率为： 99.07407407407408
# 10000张测试集合中的准确率为： 99.08256880733946
# 10000张测试集合中的准确率为： 99.0909090909091
# 10000张测试集合中的准确率为： 99.09909909909909
# 10000张测试集合中的准确率为： 98.88392857142857
# 10000张测试集合中的准确率为： 98.67256637168141
# 10000张测试集合中的准确率为： 98.68421052631578
# 10000张测试集合中的准确率为： 98.69565217391305
# 10000张测试集合中的准确率为： 98.70689655172413
# 10000张测试集合中的准确率为： 98.71794871794873
# 10000张测试集合中的准确率为： 98.72881355932203
# 10000张测试集合中的准确率为： 98.73949579831933
# 10000张测试集合中的准确率为： 98.75
# 10000张测试集合中的准确率为： 98.7603305785124
# 10000张测试集合中的准确率为： 98.77049180327869
# 10000张测试集合中的准确率为： 98.78048780487805
# 10000张测试集合中的准确率为： 98.79032258064517
# 10000张测试集合中的准确率为： 98.8
# 10000张测试集合中的准确率为： 98.80952380952381
# 10000张测试集合中的准确率为： 98.81889763779527
# 10000张测试集合中的准确率为： 98.828125
# 10000张测试集合中的准确率为： 98.83720930232558
# 10000张测试集合中的准确率为： 98.84615384615385
# 10000张测试集合中的准确率为： 98.85496183206108
# 10000张测试集合中的准确率为： 98.86363636363636
# 10000张测试集合中的准确率为： 98.87218045112782
# 10000张测试集合中的准确率为： 98.88059701492537
# 10000张测试集合中的准确率为： 98.88888888888889
# 10000张测试集合中的准确率为： 98.89705882352942
# 10000张测试集合中的准确率为： 98.90510948905109
# 10000张测试集合中的准确率为： 98.73188405797102
# 10000张测试集合中的准确率为： 98.7410071942446
# 10000张测试集合中的准确率为： 98.75
# 10000张测试集合中的准确率为： 98.75886524822694
# 10000张测试集合中的准确率为： 98.76760563380282
# 10000张测试集合中的准确率为： 98.77622377622379
# 10000张测试集合中的准确率为： 98.78472222222221
# 10000张测试集合中的准确率为： 98.79310344827587
# 10000张测试集合中的准确率为： 98.8013698630137
# 10000张测试集合中的准确率为： 98.80952380952381
# 10000张测试集合中的准确率为： 98.81756756756756
# 10000张测试集合中的准确率为： 98.8255033557047
# 10000张测试集合中的准确率为： 98.83333333333333
# 10000张测试集合中的准确率为： 98.84105960264901
# 10000张测试集合中的准确率为： 98.84868421052632
# 10000张测试集合中的准确率为： 98.8562091503268
# 10000张测试集合中的准确率为： 98.86363636363636
# 10000张测试集合中的准确率为： 98.87096774193549
# 10000张测试集合中的准确率为： 98.87820512820514
# 10000张测试集合中的准确率为： 98.88535031847134
# 10000张测试集合中的准确率为： 98.89240506329115
# 10000张测试集合中的准确率为： 98.89937106918238
# 10000张测试集合中的准确率为： 98.90625
# 10000张测试集合中的准确率为： 98.91304347826086
# 10000张测试集合中的准确率为： 98.91975308641975
# 10000张测试集合中的准确率为： 98.92638036809815
# 10000张测试集合中的准确率为： 98.9329268292683
# 10000张测试集合中的准确率为： 98.7878787878788
# 10000张测试集合中的准确率为： 98.79518072289156
# 10000张测试集合中的准确率为： 98.80239520958084
# 10000张测试集合中的准确率为： 98.80952380952381
# 10000张测试集合中的准确率为： 98.66863905325444
# 10000张测试集合中的准确率为： 98.6764705882353
# 10000张测试集合中的准确率为： 98.68421052631578
# 10000张测试集合中的准确率为： 98.69186046511628
# 10000张测试集合中的准确率为： 98.69942196531792
# 10000张测试集合中的准确率为： 98.70689655172413
# 10000张测试集合中的准确率为： 98.71428571428571
# 10000张测试集合中的准确率为： 98.7215909090909
# 10000张测试集合中的准确率为： 98.72881355932203
# 10000张测试集合中的准确率为： 98.73595505617978
# 10000张测试集合中的准确率为： 98.74301675977654
# 10000张测试集合中的准确率为： 98.75
# 10000张测试集合中的准确率为： 98.75690607734806
# 10000张测试集合中的准确率为： 98.76373626373626
# 10000张测试集合中的准确率为： 98.77049180327869
# 10000张测试集合中的准确率为： 98.77717391304348
# 10000张测试集合中的准确率为： 98.78378378378379
# 10000张测试集合中的准确率为： 98.79032258064517
# 10000张测试集合中的准确率为： 98.79679144385027
# 10000张测试集合中的准确率为： 98.8031914893617
# 10000张测试集合中的准确率为： 98.80952380952381
# 10000张测试集合中的准确率为： 98.81578947368422
# 10000张测试集合中的准确率为： 98.82198952879581
# 10000张测试集合中的准确率为： 98.828125
# 10000张测试集合中的准确率为： 98.83419689119171
# 10000张测试集合中的准确率为： 98.84020618556701
# 10000张测试集合中的准确率为： 98.84615384615385
# 10000张测试集合中的准确率为： 98.85204081632652
# 10000张测试集合中的准确率为： 98.85786802030458
# 10000张测试集合中的准确率为： 98.86363636363636
# 10000张测试集合中的准确率为： 98.86934673366834
# 10000张测试集合中的准确率为： 98.875
# 10000张测试集合中的准确率为： 98.88059701492537
# 10000张测试集合中的准确率为： 98.88613861386139
# 10000张测试集合中的准确率为： 98.89162561576354
# 10000张测试集合中的准确率为： 98.89705882352942
# 10000张测试集合中的准确率为： 98.90243902439025
# 10000张测试集合中的准确率为： 98.90776699029125
# 10000张测试集合中的准确率为： 98.91304347826086
# 10000张测试集合中的准确率为： 98.91826923076923
# 10000张测试集合中的准确率为： 98.92344497607655
# 10000张测试集合中的准确率为： 98.92857142857143
# 10000张测试集合中的准确率为： 98.93364928909952
# 10000张测试集合中的准确率为： 98.93867924528303
# 10000张测试集合中的准确率为： 98.94366197183099
# 10000张测试集合中的准确率为： 98.94859813084112
# 10000张测试集合中的准确率为： 98.95348837209302
# 10000张测试集合中的准确率为： 98.95833333333334
# 10000张测试集合中的准确率为： 98.963133640553
# 10000张测试集合中的准确率为： 98.96788990825688
# 10000张测试集合中的准确率为： 98.97260273972603
# 10000张测试集合中的准确率为： 98.97727272727272
# 10000张测试集合中的准确率为： 98.98190045248869
# 10000张测试集合中的准确率为： 98.98648648648648
# 10000张测试集合中的准确率为： 98.99103139013454
# 10000张测试集合中的准确率为： 98.99553571428571
# 10000张测试集合中的准确率为： 99.0
# 10000张测试集合中的准确率为： 99.00442477876106
# 10000张测试集合中的准确率为： 99.00881057268722
# 10000张测试集合中的准确率为： 99.01315789473685
# 10000张测试集合中的准确率为： 99.0174672489083
# 10000张测试集合中的准确率为： 98.91304347826086
# 10000张测试集合中的准确率为： 98.91774891774891
# 10000张测试集合中的准确率为： 98.92241379310344
# 10000张测试集合中的准确率为： 98.92703862660944
# 10000张测试集合中的准确率为： 98.93162393162393
# 10000张测试集合中的准确率为： 98.93617021276596
# 10000张测试集合中的准确率为： 98.9406779661017
# 10000张测试集合中的准确率为： 98.83966244725738
# 10000张测试集合中的准确率为： 98.84453781512606
# 10000张测试集合中的准确率为： 98.84937238493724
# 10000张测试集合中的准确率为： 98.75
# 10000张测试集合中的准确率为： 98.7551867219917
# 10000张测试集合中的准确率为： 98.7603305785124
# 10000张测试集合中的准确率为： 98.76543209876543
# 10000张测试集合中的准确率为： 98.77049180327869
# 10000张测试集合中的准确率为： 98.77551020408163
# 10000张测试集合中的准确率为： 98.78048780487805
# 10000张测试集合中的准确率为： 98.78542510121457
# 10000张测试集合中的准确率为： 98.79032258064517
# 10000张测试集合中的准确率为： 98.79518072289156
# 10000张测试集合中的准确率为： 98.8
# 10000张测试集合中的准确率为： 98.80478087649402
# 10000张测试集合中的准确率为： 98.80952380952381
# 10000张测试集合中的准确率为： 98.81422924901186
# 10000张测试集合中的准确率为： 98.72047244094489
# 10000张测试集合中的准确率为： 98.72549019607844
# 10000张测试集合中的准确率为： 98.73046875
# 10000张测试集合中的准确率为： 98.73540856031128
# 10000张测试集合中的准确率为： 98.74031007751938
# 10000张测试集合中的准确率为： 98.74517374517374
# 10000张测试集合中的准确率为： 98.65384615384616
# 10000张测试集合中的准确率为： 98.65900383141762
# 10000张测试集合中的准确率为： 98.66412213740458
# 10000张测试集合中的准确率为： 98.66920152091255
# 10000张测试集合中的准确率为： 98.67424242424242
# 10000张测试集合中的准确率为： 98.67924528301887
# 10000张测试集合中的准确率为： 98.68421052631578
# 10000张测试集合中的准确率为： 98.68913857677903
# 10000张测试集合中的准确率为： 98.69402985074626
# 10000张测试集合中的准确率为： 98.69888475836431
# 10000张测试集合中的准确率为： 98.70370370370371
# 10000张测试集合中的准确率为： 98.70848708487084
# 10000张测试集合中的准确率为： 98.71323529411765
# 10000张测试集合中的准确率为： 98.71794871794873
# 10000张测试集合中的准确率为： 98.72262773722628
# 10000张测试集合中的准确率为： 98.72727272727273
# 10000张测试集合中的准确率为： 98.73188405797102
# 10000张测试集合中的准确率为： 98.73646209386283
# 10000张测试集合中的准确率为： 98.7410071942446
# 10000张测试集合中的准确率为： 98.65591397849462
# 10000张测试集合中的准确率为： 98.66071428571429
# 10000张测试集合中的准确率为： 98.66548042704626
# 10000张测试集合中的准确率为： 98.67021276595744
# 10000张测试集合中的准确率为： 98.67491166077738
# 10000张测试集合中的准确率为： 98.67957746478874
# 10000张测试集合中的准确率为： 98.68421052631578
# 10000张测试集合中的准确率为： 98.68881118881119
# 10000张测试集合中的准确率为： 98.69337979094077
# 10000张测试集合中的准确率为： 98.69791666666666
# 10000张测试集合中的准确率为： 98.70242214532871
# 10000张测试集合中的准确率为： 98.62068965517241
# 10000张测试集合中的准确率为： 98.62542955326461
# 10000张测试集合中的准确率为： 98.63013698630137
# 10000张测试集合中的准确率为： 98.63481228668942
# 10000张测试集合中的准确率为： 98.63945578231292
# 10000张测试集合中的准确率为： 98.5593220338983
# 10000张测试集合中的准确率为： 98.47972972972973
# 10000张测试集合中的准确率为： 98.48484848484848
# 10000张测试集合中的准确率为： 98.48993288590604
# 10000张测试集合中的准确率为： 98.49498327759197
# 10000张测试集合中的准确率为： 98.5
# 10000张测试集合中的准确率为： 98.50498338870432
# 10000张测试集合中的准确率为： 98.50993377483444
# 10000张测试集合中的准确率为： 98.51485148514851
# 10000张测试集合中的准确率为： 98.51973684210526
# 10000张测试集合中的准确率为： 98.52459016393442
# 10000张测试集合中的准确率为： 98.52941176470588
# 10000张测试集合中的准确率为： 98.45276872964169
# 10000张测试集合中的准确率为： 98.45779220779221
# 10000张测试集合中的准确率为： 98.38187702265373
# 10000张测试集合中的准确率为： 98.38709677419355
# 10000张测试集合中的准确率为： 98.39228295819936
# 10000张测试集合中的准确率为： 98.3974358974359
# 10000张测试集合中的准确率为： 98.40255591054313
# 10000张测试集合中的准确率为： 98.40764331210191
# 10000张测试集合中的准确率为： 98.4126984126984
# 10000张测试集合中的准确率为： 98.33860759493672
# 10000张测试集合中的准确率为： 98.34384858044164
# 10000张测试集合中的准确率为： 98.34905660377359
# 10000张测试集合中的准确率为： 98.35423197492163
# 10000张测试集合中的准确率为： 98.359375
# 10000张测试集合中的准确率为： 98.36448598130842
# 10000张测试集合中的准确率为： 98.36956521739131
# 10000张测试集合中的准确率为： 98.37461300309597
# 10000张测试集合中的准确率为： 98.37962962962963
# 10000张测试集合中的准确率为： 98.38461538461539
# 10000张测试集合中的准确率为： 98.38957055214725
# 10000张测试集合中的准确率为： 98.39449541284404
# 10000张测试集合中的准确率为： 98.39939024390245
# 10000张测试集合中的准确率为： 98.40425531914893
# 10000张测试集合中的准确率为： 98.33333333333333
# 10000张测试集合中的准确率为： 98.33836858006042
# 10000张测试集合中的准确率为： 98.26807228915662
# 10000张测试集合中的准确率为： 98.1981981981982
# 10000张测试集合中的准确率为： 98.20359281437125
# 10000张测试集合中的准确率为： 98.2089552238806
# 10000张测试集合中的准确率为： 98.21428571428571
# 10000张测试集合中的准确率为： 98.21958456973294
# 10000张测试集合中的准确率为： 98.22485207100591
# 10000张测试集合中的准确率为： 98.23008849557522
# 10000张测试集合中的准确率为： 98.23529411764706
# 10000张测试集合中的准确率为： 98.24046920821115
# 10000张测试集合中的准确率为： 98.17251461988305
# 10000张测试集合中的准确率为： 98.17784256559767
# 10000张测试集合中的准确率为： 98.18313953488372
# 10000张测试集合中的准确率为： 98.18840579710145
# 10000张测试集合中的准确率为： 98.19364161849711
# 10000张测试集合中的准确率为： 98.19884726224784
# 10000张测试集合中的准确率为： 98.20402298850574
# 10000张测试集合中的准确率为： 98.13753581661892
# 10000张测试集合中的准确率为： 98.14285714285714
# 10000张测试集合中的准确率为： 98.14814814814815
# 10000张测试集合中的准确率为： 98.1534090909091
# 10000张测试集合中的准确率为： 98.15864022662889
# 10000张测试集合中的准确率为： 98.09322033898306
# 10000张测试集合中的准确率为： 98.09859154929578
# 10000张测试集合中的准确率为： 98.10393258426966
# 10000张测试集合中的准确率为： 98.10924369747899
# 10000张测试集合中的准确率为： 98.1145251396648
# 10000张测试集合中的准确率为： 98.11977715877437
# 10000张测试集合中的准确率为： 98.125
# 10000张测试集合中的准确率为： 98.13019390581718
# 10000张测试集合中的准确率为： 98.1353591160221
# 10000张测试集合中的准确率为： 98.14049586776859
# 10000张测试集合中的准确率为： 98.1456043956044
# 10000张测试集合中的准确率为： 98.15068493150685
# 10000张测试集合中的准确率为： 98.15573770491804
# 10000张测试集合中的准确率为： 98.16076294277929
# 10000张测试集合中的准确率为： 98.16576086956522
# 10000张测试集合中的准确率为： 98.17073170731707
# 10000张测试集合中的准确率为： 98.17567567567568
# 10000张测试集合中的准确率为： 98.18059299191376
# 10000张测试集合中的准确率为： 98.18548387096774
# 10000张测试集合中的准确率为： 98.19034852546918
# 10000张测试集合中的准确率为： 98.1951871657754
# 10000张测试集合中的准确率为： 98.2
# 10000张测试集合中的准确率为： 98.20478723404256
# 10000张测试集合中的准确率为： 98.20954907161804
# 10000张测试集合中的准确率为： 98.21428571428571
# 10000张测试集合中的准确率为： 98.21899736147758
# 10000张测试集合中的准确率为： 98.22368421052632
# 10000张测试集合中的准确率为： 98.16272965879264
# 10000张测试集合中的准确率为： 98.1020942408377
# 10000张测试集合中的准确率为： 98.10704960835508
# 10000张测试集合中的准确率为： 98.11197916666666
# 10000张测试集合中的准确率为： 98.11688311688312
# 10000张测试集合中的准确率为： 98.12176165803109
# 10000张测试集合中的准确率为： 98.1266149870801
# 10000张测试集合中的准确率为： 98.06701030927834
# 10000张测试集合中的准确率为： 98.00771208226222
# 10000张测试集合中的准确率为： 98.01282051282051
# 10000张测试集合中的准确率为： 98.01790281329923
# 10000张测试集合中的准确率为： 98.02295918367348
# 10000张测试集合中的准确率为： 98.02798982188295
# 10000张测试集合中的准确率为： 98.03299492385787
# 10000张测试集合中的准确率为： 98.0379746835443
# 10000张测试集合中的准确率为： 98.04292929292929
# 10000张测试集合中的准确率为： 98.04785894206549
# 10000张测试集合中的准确率为： 98.05276381909547
# 10000张测试集合中的准确率为： 98.05764411027569
# 10000张测试集合中的准确率为： 98.0625
# 10000张测试集合中的准确率为： 98.06733167082294
# 10000张测试集合中的准确率为： 98.07213930348259
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.08168316831683
# 10000张测试集合中的准确率为： 98.08641975308642
# 10000张测试集合中的准确率为： 98.0295566502463
# 10000张测试集合中的准确率为： 98.03439803439802
# 10000张测试集合中的准确率为： 98.0392156862745
# 10000张测试集合中的准确率为： 98.0440097799511
# 10000张测试集合中的准确率为： 98.04878048780488
# 10000张测试集合中的准确率为： 98.05352798053528
# 10000张测试集合中的准确率为： 98.05825242718447
# 10000张测试集合中的准确率为： 98.06295399515739
# 10000张测试集合中的准确率为： 98.06763285024155
# 10000张测试集合中的准确率为： 98.0722891566265
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.08153477218225
# 10000张测试集合中的准确率为： 98.08612440191388
# 10000张测试集合中的准确率为： 98.09069212410502
# 10000张测试集合中的准确率为： 98.09523809523809
# 10000张测试集合中的准确率为： 98.04038004750593
# 10000张测试集合中的准确率为： 98.04502369668246
# 10000张测试集合中的准确率为： 98.04964539007092
# 10000张测试集合中的准确率为： 98.05424528301887
# 10000张测试集合中的准确率为： 98.05882352941177
# 10000张测试集合中的准确率为： 98.06338028169014
# 10000张测试集合中的准确率为： 98.06791569086651
# 10000张测试集合中的准确率为： 98.01401869158879
# 10000张测试集合中的准确率为： 98.01864801864801
# 10000张测试集合中的准确率为： 98.0232558139535
# 10000张测试集合中的准确率为： 98.02784222737819
# 10000张测试集合中的准确率为： 98.0324074074074
# 10000张测试集合中的准确率为： 98.03695150115473
# 10000张测试集合中的准确率为： 98.04147465437788
# 10000张测试集合中的准确率为： 98.04597701149426
# 10000张测试集合中的准确率为： 98.05045871559633
# 10000张测试集合中的准确率为： 98.05491990846681
# 10000张测试集合中的准确率为： 98.0593607305936
# 10000张测试集合中的准确率为： 98.0637813211845
# 10000张测试集合中的准确率为： 98.06818181818183
# 10000张测试集合中的准确率为： 98.07256235827666
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.08126410835214
# 10000张测试集合中的准确率为： 98.08558558558559
# 10000张测试集合中的准确率为： 98.08988764044943
# 10000张测试集合中的准确率为： 98.09417040358744
# 10000张测试集合中的准确率为： 98.09843400447427
# 10000张测试集合中的准确率为： 98.10267857142857
# 10000张测试集合中的准确率为： 98.10690423162583
# 10000张测试集合中的准确率为： 98.11111111111111
# 10000张测试集合中的准确率为： 98.11529933481154
# 10000张测试集合中的准确率为： 98.11946902654867
# 10000张测试集合中的准确率为： 98.12362030905078
# 10000张测试集合中的准确率为： 98.12775330396477
# 10000张测试集合中的准确率为： 98.13186813186813
# 10000张测试集合中的准确率为： 98.1359649122807
# 10000张测试集合中的准确率为： 98.14004376367615
# 10000张测试集合中的准确率为： 98.14410480349345
# 10000张测试集合中的准确率为： 98.14814814814815
# 10000张测试集合中的准确率为： 98.15217391304348
# 10000张测试集合中的准确率为： 98.15618221258134
# 10000张测试集合中的准确率为： 98.16017316017316
# 10000张测试集合中的准确率为： 98.16414686825054
# 10000张测试集合中的准确率为： 98.16810344827587
# 10000张测试集合中的准确率为： 98.17204301075269
# 10000张测试集合中的准确率为： 98.17596566523605
# 10000张测试集合中的准确率为： 98.17987152034262
# 10000张测试集合中的准确率为： 98.18376068376068
# 10000张测试集合中的准确率为： 98.18763326226014
# 10000张测试集合中的准确率为： 98.13829787234043
# 10000张测试集合中的准确率为： 98.14225053078556
# 10000张测试集合中的准确率为： 98.14618644067797
# 10000张测试集合中的准确率为： 98.15010570824523
# 10000张测试集合中的准确率为： 98.15400843881856
# 10000张测试集合中的准确率为： 98.15789473684211
# 10000张测试集合中的准确率为： 98.10924369747899
# 10000张测试集合中的准确率为： 98.11320754716981
# 10000张测试集合中的准确率为： 98.11715481171548
# 10000张测试集合中的准确率为： 98.12108559498957
# 10000张测试集合中的准确率为： 98.125
# 10000张测试集合中的准确率为： 98.12889812889813
# 10000张测试集合中的准确率为： 98.13278008298755
# 10000张测试集合中的准确率为： 98.13664596273291
# 10000张测试集合中的准确率为： 98.14049586776859
# 10000张测试集合中的准确率为： 98.14432989690721
# 10000张测试集合中的准确率为： 98.09670781893004
# 10000张测试集合中的准确率为： 98.1006160164271
# 10000张测试集合中的准确率为： 98.10450819672131
# 10000张测试集合中的准确率为： 98.10838445807771
# 10000张测试集合中的准确率为： 98.11224489795919
# 10000张测试集合中的准确率为： 98.11608961303462
# 10000张测试集合中的准确率为： 98.119918699187
# 10000张测试集合中的准确率为： 98.1237322515213
# 10000张测试集合中的准确率为： 98.12753036437248
# 10000张测试集合中的准确率为： 98.13131313131314
# 10000张测试集合中的准确率为： 98.13508064516128
# 10000张测试集合中的准确率为： 98.13883299798792
# 10000张测试集合中的准确率为： 98.14257028112449
# 10000张测试集合中的准确率为： 98.14629258517033
# 10000张测试集合中的准确率为： 98.15
# 10000张测试集合中的准确率为： 98.15369261477046
# 10000张测试集合中的准确率为： 98.15737051792829
# 10000张测试集合中的准确率为： 98.1610337972167
# 10000张测试集合中的准确率为： 98.16468253968253
# 10000张测试集合中的准确率为： 98.16831683168317
# 10000张测试集合中的准确率为： 98.17193675889328
# 10000张测试集合中的准确率为： 98.17554240631164
# 10000张测试集合中的准确率为： 98.17913385826772
# 10000张测试集合中的准确率为： 98.1335952848723
# 10000张测试集合中的准确率为： 98.13725490196077
# 10000张测试集合中的准确率为： 98.09197651663405
# 10000张测试集合中的准确率为： 98.095703125
# 10000张测试集合中的准确率为： 98.09941520467837
# 10000张测试集合中的准确率为： 98.10311284046692
# 10000张测试集合中的准确率为： 98.10679611650485
# 10000张测试集合中的准确率为： 98.11046511627907
# 10000张测试集合中的准确率为： 98.11411992263056
# 10000张测试集合中的准确率为： 98.06949806949807
# 10000张测试集合中的准确率为： 98.07321772639692
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.0806142034549
# 10000张测试集合中的准确率为： 98.08429118773945
# 10000张测试集合中的准确率为： 98.08795411089865
# 10000张测试集合中的准确率为： 98.09160305343512
# 10000张测试集合中的准确率为： 98.09523809523809
# 10000张测试集合中的准确率为： 98.09885931558935
# 10000张测试集合中的准确率为： 98.10246679316889
# 10000张测试集合中的准确率为： 98.10606060606061
# 10000张测试集合中的准确率为： 98.10964083175804
# 10000张测试集合中的准确率为： 98.06603773584905
# 10000张测试集合中的准确率为： 98.06967984934086
# 10000张测试集合中的准确率为： 98.07330827067669
# 10000张测试集合中的准确率为： 97.98311444652909
# 10000张测试集合中的准确率为： 97.94007490636703
# 10000张测试集合中的准确率为： 97.94392523364486
# 10000张测试集合中的准确率为： 97.94776119402985
# 10000张测试集合中的准确率为： 97.95158286778398
# 10000张测试集合中的准确率为： 97.90892193308551
# 10000张测试集合中的准确率为： 97.91280148423006
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.92051756007393
# 10000张测试集合中的准确率为： 97.92435424354244
# 10000张测试集合中的准确率为： 97.92817679558011
# 10000张测试集合中的准确率为： 97.93198529411765
# 10000张测试集合中的准确率为： 97.93577981651376
# 10000张测试集合中的准确率为： 97.93956043956044
# 10000张测试集合中的准确率为： 97.94332723948813
# 10000张测试集合中的准确率为： 97.9470802919708
# 10000张测试集合中的准确率为： 97.90528233151184
# 10000张测试集合中的准确率为： 97.9090909090909
# 10000张测试集合中的准确率为： 97.91288566243193
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.92043399638337
# 10000张测试集合中的准确率为： 97.92418772563177
# 10000张测试集合中的准确率为： 97.92792792792793
# 10000张测试集合中的准确率为： 97.931654676259
# 10000张测试集合中的准确率为： 97.93536804308796
# 10000张测试集合中的准确率为： 97.93906810035843
# 10000张测试集合中的准确率为： 97.94275491949911
# 10000张测试集合中的准确率为： 97.94642857142857
# 10000张测试集合中的准确率为： 97.95008912655972
# 10000张测试集合中的准确率为： 97.95373665480427
# 10000张测试集合中的准确率为： 97.95737122557726
# 10000张测试集合中的准确率为： 97.96099290780141
# 10000张测试集合中的准确率为： 97.96460176991151
# 10000张测试集合中的准确率为： 97.96819787985865
# 10000张测试集合中的准确率为： 97.92768959435627
# 10000张测试集合中的准确率为： 97.93133802816901
# 10000张测试集合中的准确率为： 97.93497363796133
# 10000张测试集合中的准确率为： 97.93859649122807
# 10000张测试集合中的准确率为： 97.94220665499125
# 10000张测试集合中的准确率为： 97.9458041958042
# 10000张测试集合中的准确率为： 97.94938917975567
# 10000张测试集合中的准确率为： 97.90940766550523
# 10000张测试集合中的准确率为： 97.91304347826087
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.92027729636048
# 10000张测试集合中的准确率为： 97.92387543252595
# 10000张测试集合中的准确率为： 97.92746113989638
# 10000张测试集合中的准确率为： 97.93103448275862
# 10000张测试集合中的准确率为： 97.93459552495698
# 10000张测试集合中的准确率为： 97.89518900343643
# 10000张测试集合中的准确率为： 97.89879931389366
# 10000张测试集合中的准确率为： 97.90239726027397
# 10000张测试集合中的准确率为： 97.9059829059829
# 10000张测试集合中的准确率为： 97.90955631399318
# 10000张测试集合中的准确率为： 97.91311754684838
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.92020373514431
# 10000张测试集合中的准确率为： 97.92372881355932
# 10000张测试集合中的准确率为： 97.92724196277496
# 10000张测试集合中的准确率为： 97.93074324324324
# 10000张测试集合中的准确率为： 97.8920741989882
# 10000张测试集合中的准确率为： 97.89562289562289
# 10000张测试集合中的准确率为： 97.89915966386555
# 10000张测试集合中的准确率为： 97.90268456375838
# 10000张测试集合中的准确率为： 97.8643216080402
# 10000张测试集合中的准确率为： 97.86789297658864
# 10000张测试集合中的准确率为： 97.87145242070116
# 10000张测试集合中的准确率为： 97.875
# 10000张测试集合中的准确率为： 97.87853577371048
# 10000张测试集合中的准确率为： 97.88205980066445
# 10000张测试集合中的准确率为： 97.88557213930348
# 10000张测试集合中的准确率为： 97.84768211920529
# 10000张测试集合中的准确率为： 97.85123966942149
# 10000张测试集合中的准确率为： 97.85478547854785
# 10000张测试集合中的准确率为： 97.85831960461286
# 10000张测试集合中的准确率为： 97.86184210526315
# 10000张测试集合中的准确率为： 97.86535303776684
# 10000张测试集合中的准确率为： 97.8688524590164
# 10000张测试集合中的准确率为： 97.87234042553192
# 10000张测试集合中的准确率为： 97.83496732026144
# 10000张测试集合中的准确率为： 97.83849918433931
# 10000张测试集合中的准确率为： 97.84201954397395
# 10000张测试集合中的准确率为： 97.84552845528455
# 10000张测试集合中的准确率为： 97.84902597402598
# 10000张测试集合中的准确率为： 97.85251215559157
# 10000张测试集合中的准确率为： 97.85598705501619
# 10000张测试集合中的准确率为： 97.859450726979
# 10000张测试集合中的准确率为： 97.86290322580645
# 10000张测试集合中的准确率为： 97.86634460547504
# 10000张测试集合中的准确率为： 97.86977491961414
# 10000张测试集合中的准确率为： 97.87319422150883
# 10000张测试集合中的准确率为： 97.87660256410257
# 10000张测试集合中的准确率为： 97.88
# 10000张测试集合中的准确率为： 97.88338658146965
# 10000张测试集合中的准确率为： 97.88676236044657
# 10000张测试集合中的准确率为： 97.89012738853503
# 10000张测试集合中的准确率为： 97.89348171701113
# 10000张测试集合中的准确率为： 97.89682539682539
# 10000张测试集合中的准确率为： 97.90015847860539
# 10000张测试集合中的准确率为： 97.90348101265823
# 10000张测试集合中的准确率为： 97.90679304897314
# 10000张测试集合中的准确率为： 97.91009463722398
# 10000张测试集合中的准确率为： 97.91338582677164
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91993720565148
# 10000张测试集合中的准确率为： 97.92319749216301
# 10000张测试集合中的准确率为： 97.9264475743349
# 10000张测试集合中的准确率为： 97.9296875
# 10000张测试集合中的准确率为： 97.93291731669267
# 10000张测试集合中的准确率为： 97.93613707165109
# 10000张测试集合中的准确率为： 97.93934681181959
# 10000张测试集合中的准确率为： 97.94254658385093
# 10000张测试集合中的准确率为： 97.94573643410854
# 10000张测试集合中的准确率为： 97.91021671826626
# 10000张测试集合中的准确率为： 97.91344667697064
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91987673343606
# 10000张测试集合中的准确率为： 97.88461538461539
# 10000张测试集合中的准确率为： 97.88786482334869
# 10000张测试集合中的准确率为： 97.89110429447852
# 10000张测试集合中的准确率为： 97.89433384379785
# 10000张测试集合中的准确率为： 97.89755351681957
# 10000张测试集合中的准确率为： 97.90076335877863
# 10000张测试集合中的准确率为： 97.90396341463415
# 10000张测试集合中的准确率为： 97.90715372907154
# 10000张测试集合中的准确率为： 97.91033434650456
# 10000张测试集合中的准确率为： 97.91350531107739
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91981845688352
# 10000张测试集合中的准确率为： 97.92296072507553
# 10000张测试集合中的准确率为： 97.88838612368023
# 10000张测试集合中的准确率为： 97.8539156626506
# 10000张测试集合中的准确率为： 97.85714285714285
# 10000张测试集合中的准确率为： 97.86036036036036
# 10000张测试集合中的准确率为： 97.86356821589204
# 10000张测试集合中的准确率为： 97.86676646706587
# 10000张测试集合中的准确率为： 97.86995515695067
# 10000张测试集合中的准确率为： 97.87313432835822
# 10000张测试集合中的准确率为： 97.87630402384501
# 10000张测试集合中的准确率为： 97.87946428571429
# 10000张测试集合中的准确率为： 97.88261515601782
# 10000张测试集合中的准确率为： 97.88575667655786
# 10000张测试集合中的准确率为： 97.88888888888889
# 10000张测试集合中的准确率为： 97.89201183431953
# 10000张测试集合中的准确率为： 97.89512555391433
# 10000张测试集合中的准确率为： 97.89823008849558
# 10000张测试集合中的准确率为： 97.90132547864506
# 10000张测试集合中的准确率为： 97.90441176470588
# 10000张测试集合中的准确率为： 97.87077826725404
# 10000张测试集合中的准确率为： 97.87390029325513
# 10000张测试集合中的准确率为： 97.87701317715958
# 10000张测试集合中的准确率为： 97.88011695906432
# 10000张测试集合中的准确率为： 97.88321167883211
# 10000张测试集合中的准确率为： 97.84985422740526
# 10000张测试集合中的准确率为： 97.85298398835516
# 10000张测试集合中的准确率为： 97.8561046511628
# 10000张测试集合中的准确率为： 97.85921625544267
# 10000张测试集合中的准确率为： 97.8623188405797
# 10000张测试集合中的准确率为： 97.86541244573083
# 10000张测试集合中的准确率为： 97.86849710982659
# 10000张测试集合中的准确率为： 97.87157287157288
# 10000张测试集合中的准确率为： 97.87463976945246
# 10000张测试集合中的准确率为： 97.87769784172662
# 10000张测试集合中的准确率为： 97.88074712643679
# 10000张测试集合中的准确率为： 97.88378766140603
# 10000张测试集合中的准确率为： 97.88681948424069
# 10000张测试集合中的准确率为： 97.8898426323319
# 10000张测试集合中的准确率为： 97.89285714285715
# 10000张测试集合中的准确率为： 97.89586305278173
# 10000张测试集合中的准确率为： 97.89886039886039
# 10000张测试集合中的准确率为： 97.9018492176387
# 10000张测试集合中的准确率为： 97.90482954545455
# 10000张测试集合中的准确率为： 97.90780141843972
# 10000张测试集合中的准确率为： 97.91076487252126
# 10000张测试集合中的准确率为： 97.91371994342292
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91960507757405
# 10000张测试集合中的准确率为： 97.9225352112676
# 10000张测试集合中的准确率为： 97.9254571026723
# 10000张测试集合中的准确率为： 97.92837078651685
# 10000张测试集合中的准确率为： 97.9312762973352
# 10000张测试集合中的准确率为： 97.93417366946778
# 10000张测试集合中的准确率为： 97.93706293706293
# 10000张测试集合中的准确率为： 97.93994413407822
# 10000张测试集合中的准确率为： 97.94281729428172
# 10000张测试集合中的准确率为： 97.94568245125348
# 10000张测试集合中的准确率为： 97.94853963838665
# 10000张测试集合中的准确率为： 97.95138888888889
# 10000张测试集合中的准确率为： 97.95423023578364
# 10000张测试集合中的准确率为： 97.95706371191135
# 10000张测试集合中的准确率为： 97.95988934993083
# 10000张测试集合中的准确率为： 97.96270718232044
# 10000张测试集合中的准确率为： 97.9655172413793
# 10000张测试集合中的准确率为： 97.96831955922865
# 10000张测试集合中的准确率为： 97.97111416781293
# 10000张测试集合中的准确率为： 97.9739010989011
# 10000张测试集合中的准确率为： 97.97668038408779
# 10000张测试集合中的准确率为： 97.97945205479452
# 10000张测试集合中的准确率为： 97.98221614227086
# 10000张测试集合中的准确率为： 97.95081967213115
# 10000张测试集合中的准确率为： 97.95361527967258
# 10000张测试集合中的准确率为： 97.95640326975476
# 10000张测试集合中的准确率为： 97.92517006802721
# 10000张测试集合中的准确率为： 97.92798913043478
# 10000张测试集合中的准确率为： 97.93080054274084
# 10000张测试集合中的准确率为： 97.93360433604336
# 10000张测试集合中的准确率为： 97.90257104194858
# 10000张测试集合中的准确率为： 97.9054054054054
# 10000张测试集合中的准确率为： 97.90823211875843
# 10000张测试集合中的准确率为： 97.911051212938
# 10000张测试集合中的准确率为： 97.91386271870795
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91946308724833
# 10000张测试集合中的准确率为： 97.92225201072387
# 10000张测试集合中的准确率为： 97.92503346720214
# 10000张测试集合中的准确率为： 97.92780748663101
# 10000张测试集合中的准确率为： 97.93057409879839
# 10000张测试集合中的准确率为： 97.93333333333332
# 10000张测试集合中的准确率为： 97.93608521970705
# 10000张测试集合中的准确率为： 97.90558510638297
# 10000张测试集合中的准确率为： 97.90836653386454
# 10000张测试集合中的准确率为： 97.91114058355438
# 10000张测试集合中的准确率为： 97.91390728476821
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91941875825627
# 10000张测试集合中的准确率为： 97.9221635883905
# 10000张测试集合中的准确率为： 97.92490118577075
# 10000张测试集合中的准确率为： 97.92763157894737
# 10000张测试集合中的准确率为： 97.93035479632063
# 10000张测试集合中的准确率为： 97.93307086614173
# 10000张测试集合中的准确率为： 97.93577981651376
# 10000张测试集合中的准确率为： 97.93848167539268
# 10000张测试集合中的准确率为： 97.94117647058823
# 10000张测试集合中的准确率为： 97.94386422976501
# 10000张测试集合中的准确率为： 97.94654498044328
# 10000张测试集合中的准确率为： 97.94921875
# 10000张测试集合中的准确率为： 97.9518855656697
# 10000张测试集合中的准确率为： 97.95454545454545
# 10000张测试集合中的准确率为： 97.95719844357976
# 10000张测试集合中的准确率为： 97.95984455958549
# 10000张测试集合中的准确率为： 97.96248382923673
# 10000张测试集合中的准确率为： 97.96511627906976
# 10000张测试集合中的准确率为： 97.96774193548387
# 10000张测试集合中的准确率为： 97.97036082474226
# 10000张测试集合中的准确率为： 97.97297297297297
# 10000张测试集合中的准确率为： 97.97557840616966
# 10000张测试集合中的准确率为： 97.97817715019256
# 10000张测试集合中的准确率为： 97.98076923076923
# 10000张测试集合中的准确率为： 97.98335467349551
# 10000张测试集合中的准确率为： 97.98593350383632
# 10000张测试集合中的准确率为： 97.98850574712644
# 10000张测试集合中的准确率为： 97.99107142857143
# 10000张测试集合中的准确率为： 97.9936305732484
# 10000张测试集合中的准确率为： 97.99618320610686
# 10000张测试集合中的准确率为： 97.9987293519695
# 10000张测试集合中的准确率为： 98.00126903553299
# 10000张测试集合中的准确率为： 98.00380228136882
# 10000张测试集合中的准确率为： 98.00632911392405
# 10000张测试集合中的准确率为： 98.00884955752213
# 10000张测试集合中的准确率为： 98.01136363636364
# 10000张测试集合中的准确率为： 98.01387137452711
# 10000张测试集合中的准确率为： 98.01637279596977
# 10000张测试集合中的准确率为： 98.0188679245283
# 10000张测试集合中的准确率为： 98.0213567839196
# 10000张测试集合中的准确率为： 98.02383939774153
# 10000张测试集合中的准确率为： 97.99498746867168
# 10000张测试集合中的准确率为： 97.99749687108886
# 10000张测试集合中的准确率为： 98.0
# 10000张测试集合中的准确率为： 98.00249687890137
# 10000张测试集合中的准确率为： 98.00498753117208
# 10000张测试集合中的准确率为： 98.00747198007473
# 10000张测试集合中的准确率为： 98.00995024875621
# 10000张测试集合中的准确率为： 98.01242236024845
# 10000张测试集合中的准确率为： 98.01488833746899
# 10000张测试集合中的准确率为： 97.98636926889715
# 10000张测试集合中的准确率为： 97.98886138613861
# 10000张测试集合中的准确率为： 97.99134734239803
# 10000张测试集合中的准确率为： 97.99382716049382
# 10000张测试集合中的准确率为： 97.99630086313194
# 10000张测试集合中的准确率为： 97.9987684729064
# 10000张测试集合中的准确率为： 98.00123001230013
# 10000张测试集合中的准确率为： 98.0036855036855
# 10000张测试集合中的准确率为： 98.00613496932516
# 10000张测试集合中的准确率为： 98.00857843137256
# 10000张测试集合中的准确率为： 98.0110159118727
# 10000张测试集合中的准确率为： 98.01344743276283
# 10000张测试集合中的准确率为： 98.01587301587301
# 10000张测试集合中的准确率为： 98.01829268292683
# 10000张测试集合中的准确率为： 97.99025578562728
# 10000张测试集合中的准确率为： 97.99270072992701
# 10000张测试集合中的准确率为： 97.9951397326853
# 10000张测试集合中的准确率为： 97.99757281553399
# 10000张测试集合中的准确率为： 98.0
# 10000张测试集合中的准确率为： 98.00242130750605
# 10000张测试集合中的准确率为： 98.00483675937122
# 10000张测试集合中的准确率为： 98.0072463768116
# 10000张测试集合中的准确率为： 98.0096501809409
# 10000张测试集合中的准确率为： 98.01204819277109
# 10000张测试集合中的准确率为： 98.014440433213
# 10000张测试集合中的准确率为： 98.01682692307693
# 10000张测试集合中的准确率为： 98.01920768307323
# 10000张测试集合中的准确率为： 98.02158273381295
# 10000张测试集合中的准确率为： 98.02395209580838
# 10000张测试集合中的准确率为： 98.02631578947368
# 10000张测试集合中的准确率为： 98.02867383512545
# 10000张测试集合中的准确率为： 98.0310262529833
# 10000张测试集合中的准确率为： 98.03337306317044
# 10000张测试集合中的准确率为： 98.03571428571428
# 10000张测试集合中的准确率为： 98.03804994054697
# 10000张测试集合中的准确率为： 98.04038004750593
# 10000张测试集合中的准确率为： 98.04270462633453
# 10000张测试集合中的准确率为： 98.04502369668246
# 10000张测试集合中的准确率为： 98.04733727810651
# 10000张测试集合中的准确率为： 98.04964539007092
# 10000张测试集合中的准确率为： 98.05194805194806
# 10000张测试集合中的准确率为： 98.05424528301887
# 10000张测试集合中的准确率为： 98.0565371024735
# 10000张测试集合中的准确率为： 98.05882352941177
# 10000张测试集合中的准确率为： 98.06110458284371
# 10000张测试集合中的准确率为： 98.06338028169014
# 10000张测试集合中的准确率为： 98.06565064478312
# 10000张测试集合中的准确率为： 98.06791569086651
# 10000张测试集合中的准确率为： 98.0701754385965
# 10000张测试集合中的准确率为： 98.04322429906543
# 10000张测试集合中的准确率为： 98.04550758459743
# 10000张测试集合中的准确率为： 98.04778554778555
# 10000张测试集合中的准确率为： 98.05005820721769
# 10000张测试集合中的准确率为： 98.05232558139535
# 10000张测试集合中的准确率为： 98.02555168408827
# 10000张测试集合中的准确率为： 98.02784222737819
# 10000张测试集合中的准确率为： 98.00115874855156
# 10000张测试集合中的准确率为： 98.00347222222221
# 10000张测试集合中的准确率为： 98.00578034682081
# 10000张测试集合中的准确率为： 98.0080831408776
# 10000张测试集合中的准确率为： 98.01038062283737
# 10000张测试集合中的准确率为： 98.01267281105991
# 10000张测试集合中的准确率为： 98.01495972382048
# 10000张测试集合中的准确率为： 98.01724137931035
# 10000张测试集合中的准确率为： 98.0195177956372
# 10000张测试集合中的准确率为： 98.02178899082568
# 10000张测试集合中的准确率为： 98.02405498281786
# 10000张测试集合中的准确率为： 98.02631578947368
# 10000张测试集合中的准确率为： 98.02857142857142
# 10000张测试集合中的准确率为： 98.00228310502284
# 10000张测试集合中的准确率为： 98.00456100342075
# 10000张测试集合中的准确率为： 98.00683371298405
# 10000张测试集合中的准确率为： 98.00910125142207
# 10000张测试集合中的准确率为： 98.01136363636364
# 10000张测试集合中的准确率为： 98.01362088535754
# 10000张测试集合中的准确率为： 98.01587301587301
# 10000张测试集合中的准确率为： 98.01812004530012
# 10000张测试集合中的准确率为： 98.02036199095022
# 10000张测试集合中的准确率为： 98.0225988700565
# 10000张测试集合中的准确率为： 98.02483069977427
# 10000张测试集合中的准确率为： 98.02705749718152
# 10000张测试集合中的准确率为： 98.02927927927928
# 10000张测试集合中的准确率为： 98.03149606299213
# 10000张测试集合中的准确率为： 98.03370786516854
# 10000张测试集合中的准确率为： 98.03591470258138
# 10000张测试集合中的准确率为： 98.03811659192824
# 10000张测试集合中的准确率为： 98.04031354983202
# 10000张测试集合中的准确率为： 98.04250559284117
# 10000张测试集合中的准确率为： 98.04469273743017
# 10000张测试集合中的准确率为： 98.046875
# 10000张测试集合中的准确率为： 98.0490523968785
# 10000张测试集合中的准确率为： 98.05122494432071
# 10000张测试集合中的准确率为： 98.05339265850945
# 10000张测试集合中的准确率为： 98.05555555555556
# 10000张测试集合中的准确率为： 98.05771365149833
# 10000张测试集合中的准确率为： 98.05986696230599
# 10000张测试集合中的准确率为： 98.06201550387597
# 10000张测试集合中的准确率为： 98.0641592920354
# 10000张测试集合中的准确率为： 98.06629834254143
# 10000张测试集合中的准确率为： 98.06843267108167
# 10000张测试集合中的准确率为： 98.07056229327453
# 10000张测试集合中的准确率为： 98.07268722466961
# 10000张测试集合中的准确率为： 98.07480748074808
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.07903402854006
# 10000张测试集合中的准确率为： 98.08114035087719
# 10000张测试集合中的准确率为： 98.08324205914568
# 10000张测试集合中的准确率为： 98.08533916849015
# 10000张测试集合中的准确率为： 98.08743169398907
# 10000张测试集合中的准确率为： 98.08951965065502
# 10000张测试集合中的准确率为： 98.09160305343512
# 10000张测试集合中的准确率为： 98.09368191721133
# 10000张测试集合中的准确率为： 98.09575625680087
# 10000张测试集合中的准确率为： 98.09782608695652
# 10000张测试集合中的准确率为： 98.099891422367
# 10000张测试集合中的准确率为： 98.10195227765726
# 10000张测试集合中的准确率为： 98.10400866738895
# 10000张测试集合中的准确率为： 98.10606060606061
# 10000张测试集合中的准确率为： 98.1081081081081
# 10000张测试集合中的准确率为： 98.11015118790498
# 10000张测试集合中的准确率为： 98.11218985976268
# 10000张测试集合中的准确率为： 98.11422413793103
# 10000张测试集合中的准确率为： 98.11625403659849
# 10000张测试集合中的准确率为： 98.11827956989248
# 10000张测试集合中的准确率为： 98.1203007518797
# 10000张测试集合中的准确率为： 98.09549356223177
# 10000张测试集合中的准确率为： 98.09753483386923
# 10000张测试集合中的准确率为： 98.09957173447538
# 10000张测试集合中的准确率为： 98.10160427807486
# 10000张测试集合中的准确率为： 98.10363247863248
# 10000张测试集合中的准确率为： 98.10565635005337
# 10000张测试集合中的准确率为： 98.10767590618337
# 10000张测试集合中的准确率为： 98.10969116080938
# 10000张测试集合中的准确率为： 98.11170212765957
# 10000张测试集合中的准确率为： 98.08714133900106
# 10000张测试集合中的准确率为： 98.06263269639066
# 10000张测试集合中的准确率为： 98.06468716861082
# 10000张测试集合中的准确率为： 98.0667372881356
# 10000张测试集合中的准确率为： 98.04232804232804
# 10000张测试集合中的准确率为： 98.04439746300211
# 10000张测试集合中的准确率为： 98.04646251319957
# 10000张测试集合中的准确率为： 98.04852320675106
# 10000张测试集合中的准确率为： 98.02423603793467
# 10000张测试集合中的准确率为： 98.0
# 10000张测试集合中的准确率为： 98.00210304942166
# 10000张测试集合中的准确率为： 97.97794117647058
# 10000张测试集合中的准确率为： 97.95383001049318
# 10000张测试集合中的准确率为： 97.95597484276729
# 10000张测试集合中的准确率为： 97.95811518324608
# 10000张测试集合中的准确率为： 97.9602510460251
# 10000张测试集合中的准确率为： 97.96238244514106
# 10000张测试集合中的准确率为： 97.96450939457203
# 10000张测试集合中的准确率为： 97.96663190823774
# 10000张测试集合中的准确率为： 97.96875
# 10000张测试集合中的准确率为： 97.97086368366286
# 10000张测试集合中的准确率为： 97.97297297297297
# 10000张测试集合中的准确率为： 97.9491173416407
# 10000张测试集合中的准确率为： 97.95124481327801
# 10000张测试集合中的准确率为： 97.95336787564767
# 10000张测试集合中的准确率为： 97.95548654244305
# 10000张测试集合中的准确率为： 97.95760082730092
# 10000张测试集合中的准确率为： 97.95971074380165
# 10000张测试集合中的准确率为： 97.96181630546955
# 10000张测试集合中的准确率为： 97.9639175257732
# 10000张测试集合中的准确率为： 97.96601441812565
# 10000张测试集合中的准确率为： 97.96810699588477
# 10000张测试集合中的准确率为： 97.97019527235355
# 10000张测试集合中的准确率为： 97.9722792607803
# 10000张测试集合中的准确率为： 97.97435897435898
# 10000张测试集合中的准确率为： 97.9764344262295
# 10000张测试集合中的准确率为： 97.978505629478
# 10000张测试集合中的准确率为： 97.98057259713701
# 10000张测试集合中的准确率为： 97.98263534218592
# 10000张测试集合中的准确率为： 97.98469387755102
# 10000张测试集合中的准确率为： 97.98674821610601
# 10000张测试集合中的准确率为： 97.9633401221996
# 10000张测试集合中的准确率为： 97.96541200406918
# 10000张测试集合中的准确率为： 97.96747967479675
# 10000张测试集合中的准确率为： 97.96954314720813
# 10000张测试集合中的准确率为： 97.94624746450305
# 10000张测试集合中的准确率为： 97.94832826747721
# 10000张测试集合中的准确率为： 97.9504048582996
# 10000张测试集合中的准确率为： 97.95247724974722
# 10000张测试集合中的准确率为： 97.95454545454545
# 10000张测试集合中的准确率为： 97.95660948536832
# 10000张测试集合中的准确率为： 97.95866935483872
# 10000张测试集合中的准确率为： 97.9607250755287
# 10000张测试集合中的准确率为： 97.96277665995976
# 10000张测试集合中的准确率为： 97.96482412060301
# 10000张测试集合中的准确率为： 97.96686746987952
# 10000张测试集合中的准确率为： 97.91875626880642
# 10000张测试集合中的准确率为： 97.92084168336673
# 10000张测试集合中的准确率为： 97.92292292292292
# 10000张测试集合中的准确率为： 97.925
# 10000张测试集合中的准确率为： 97.92707292707293
# 10000张测试集合中的准确率为： 97.90419161676647
# 10000张测试集合中的准确率为： 97.90628115653041
# 10000张测试集合中的准确率为： 97.90836653386454
# 10000张测试集合中的准确率为： 97.91044776119404
# 10000张测试集合中的准确率为： 97.91252485089463
# 10000张测试集合中的准确率为： 97.91459781529295
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.9187314172448
# 10000张测试集合中的准确率为： 97.92079207920791
# 10000张测试集合中的准确率为： 97.92284866468842
# 10000张测试集合中的准确率为： 97.92490118577075
# 10000张测试集合中的准确率为： 97.92694965449161
# 10000张测试集合中的准确率为： 97.92899408284023
# 10000张测试集合中的准确率为： 97.93103448275862
# 10000张测试集合中的准确率为： 97.93307086614173
# 10000张测试集合中的准确率为： 97.93510324483776
# 10000张测试集合中的准确率为： 97.93713163064834
# 10000张测试集合中的准确率为： 97.93915603532875
# 10000张测试集合中的准确率为： 97.91666666666666
# 10000张测试集合中的准确率为： 97.91870714985309
# 10000张测试集合中的准确率为： 97.92074363992172
# 10000张测试集合中的准确率为： 97.9227761485826
# 10000张测试集合中的准确率为： 97.9248046875
# 10000张测试集合中的准确率为： 97.92682926829268
# 10000张测试集合中的准确率为： 97.92884990253411
# 10000张测试集合中的准确率为： 97.93086660175267
# 10000张测试集合中的准确率为： 97.9328793774319
# 10000张测试集合中的准确率为： 97.93488824101068
# 10000张测试集合中的准确率为： 97.93689320388349
# 10000张测试集合中的准确率为： 97.93889427740058
# 10000张测试集合中的准确率为： 97.94089147286822
# 10000张测试集合中的准确率为： 97.94288480154889
# 10000张测试集合中的准确率为： 97.94487427466152
# 10000张测试集合中的准确率为： 97.94685990338165
# 10000张测试集合中的准确率为： 97.9488416988417
# 10000张测试集合中的准确率为： 97.95081967213115
# 10000张测试集合中的准确率为： 97.95279383429673
# 10000张测试集合中的准确率为： 97.95476419634264
# 10000张测试集合中的准确率为： 97.95673076923077
# 10000张测试集合中的准确率为： 97.95869356388089
# 10000张测试集合中的准确率为： 97.96065259117083
# 10000张测试集合中的准确率为： 97.96260786193672
# 10000张测试集合中的准确率为： 97.96455938697318
# 10000张测试集合中的准确率为： 97.96650717703349
# 10000张测试集合中的准确率为： 97.96845124282983
# 10000张测试集合中的准确率为： 97.97039159503342
# 10000张测试集合中的准确率为： 97.9723282442748
# 10000张测试集合中的准确率为： 97.97426120114395
# 10000张测试集合中的准确率为： 97.97619047619047
# 10000张测试集合中的准确率为： 97.97811607992388
# 10000张测试集合中的准确率为： 97.98003802281369
# 10000张测试集合中的准确率为： 97.98195631528965
# 10000张测试集合中的准确率为： 97.98387096774194
# 10000张测试集合中的准确率为： 97.98578199052133
# 10000张测试集合中的准确率为： 97.98768939393939
# 10000张测试集合中的准确率为： 97.98959318826869
# 10000张测试集合中的准确率为： 97.9914933837429
# 10000张测试集合中的准确率为： 97.99338999055713
# 10000张测试集合中的准确率为： 97.99528301886792
# 10000张测试集合中的准确率为： 97.99717247879359
# 10000张测试集合中的准确率为： 97.99905838041431
# 10000张测试集合中的准确率为： 97.97742238946378
# 10000张测试集合中的准确率为： 97.97932330827066
# 10000张测试集合中的准确率为： 97.95774647887325
# 10000张测试集合中的准确率为： 97.95966228893059
# 10000张测试集合中的准确率为： 97.96157450796626
# 10000张测试集合中的准确率为： 97.96348314606742
# 10000张测试集合中的准确率为： 97.96538821328345
# 10000张测试集合中的准确率为： 97.96728971962617
# 10000张测试集合中的准确率为： 97.96918767507002
# 10000张测试集合中的准确率为： 97.97108208955224
# 10000张测试集合中的准确率为： 97.97297297297297
# 10000张测试集合中的准确率为： 97.97486033519553
# 10000张测试集合中的准确率为： 97.97674418604652
# 10000张测试集合中的准确率为： 97.97862453531599
# 10000张测试集合中的准确率为： 97.98050139275766
# 10000张测试集合中的准确率为： 97.98237476808906
# 10000张测试集合中的准确率为： 97.98424467099166
# 10000张测试集合中的准确率为： 97.98611111111111
# 10000张测试集合中的准确率为： 97.98797409805735
# 10000张测试集合中的准确率为： 97.98983364140481
# 10000张测试集合中的准确率为： 97.99168975069253
# 10000张测试集合中的准确率为： 97.99354243542436
# 10000张测试集合中的准确率为： 97.99539170506912
# 10000张测试集合中的准确率为： 97.99723756906077
# 10000张测试集合中的准确率为： 97.99908003679853
# 10000张测试集合中的准确率为： 98.00091911764706
# 10000张测试集合中的准确率为： 98.00275482093664
# 10000张测试集合中的准确率为： 98.0045871559633
# 10000张测试集合中的准确率为： 97.98350137488544
# 10000张测试集合中的准确率为： 97.98534798534799
# 10000张测试集合中的准确率为： 97.9871912168344
# 10000张测试集合中的准确率为： 97.9890310786106
# 10000张测试集合中的准确率为： 97.99086757990868
# 10000张测试集合中的准确率为： 97.99270072992701
# 10000张测试集合中的准确率为： 97.99453053783044
# 10000张测试集合中的准确率为： 97.99635701275045
# 10000张测试集合中的准确率为： 97.99818016378526
# 10000张测试集合中的准确率为： 98.0
# 10000张测试集合中的准确率为： 98.0018165304269
# 10000张测试集合中的准确率为： 98.00362976406534
# 10000张测试集合中的准确率为： 98.00543970988214
# 10000张测试集合中的准确率为： 98.0072463768116
# 10000张测试集合中的准确率为： 98.00904977375565
# 10000张测试集合中的准确率为： 98.01084990958408
# 10000张测试集合中的准确率为： 98.01264679313459
# 10000张测试集合中的准确率为： 98.014440433213
# 10000张测试集合中的准确率为： 98.01623083859333
# 10000张测试集合中的准确率为： 98.01801801801801
# 10000张测试集合中的准确率为： 98.01980198019803
# 10000张测试集合中的准确率为： 98.02158273381295
# 10000张测试集合中的准确率为： 98.02336028751122
# 10000张测试集合中的准确率为： 98.02513464991023
# 10000张测试集合中的准确率为： 98.02690582959642
# 10000张测试集合中的准确率为： 98.02867383512545
# 10000张测试集合中的准确率为： 98.03043867502238
# 10000张测试集合中的准确率为： 98.03220035778175
# 10000张测试集合中的准确率为： 98.03395889186774
# 10000张测试集合中的准确率为： 98.03571428571428
# 10000张测试集合中的准确率为： 98.03746654772524
# 10000张测试集合中的准确率为： 98.01693404634581
# 10000张测试集合中的准确率为： 98.0186999109528
# 10000张测试集合中的准确率为： 98.02046263345196
# 10000张测试集合中的准确率为： 98.02222222222223
# 10000张测试集合中的准确率为： 98.02397868561279
# 10000张测试集合中的准确率为： 98.0257320319432
# 10000张测试集合中的准确率为： 98.02748226950354
# 10000张测试集合中的准确率为： 98.02922940655448
# 10000张测试集合中的准确率为： 98.03097345132743
# 10000张测试集合中的准确率为： 98.03271441202476
# 10000张测试集合中的准确率为： 98.03445229681978
# 10000张测试集合中的准确率为： 98.03618711385703
# 10000张测试集合中的准确率为： 98.0379188712522
# 10000张测试集合中的准确率为： 98.01762114537445
# 10000张测试集合中的准确率为： 98.0193661971831
# 10000张测试集合中的准确率为： 98.02110817941953
# 10000张测试集合中的准确率为： 98.00087873462215
# 10000张测试集合中的准确率为： 98.00263388937664
# 10000张测试集合中的准确率为： 98.00438596491227
# 10000张测试集合中的准确率为： 98.00613496932516
# 10000张测试集合中的准确率为： 98.00788091068301
# 10000张测试集合中的准确率为： 98.00962379702537
# 10000张测试集合中的准确率为： 98.01136363636364
# 10000张测试集合中的准确率为： 98.01310043668123
# 10000张测试集合中的准确率为： 98.01483420593368
# 10000张测试集合中的准确率为： 98.01656495204882
# 10000张测试集合中的准确率为： 98.01829268292683
# 10000张测试集合中的准确率为： 98.02001740644039
# 10000张测试集合中的准确率为： 98.02173913043478
# 10000张测试集合中的准确率为： 98.02345786272807
# 10000张测试集合中的准确率为： 98.02517361111111
# 10000张测试集合中的准确率为： 98.02688638334779
# 10000张测试集合中的准确率为： 98.02859618717504
# 10000张测试集合中的准确率为： 98.03030303030303
# 10000张测试集合中的准确率为： 98.03200692041523
# 10000张测试集合中的准确率为： 98.03370786516854
# 10000张测试集合中的准确率为： 98.03540587219344
# 10000张测试集合中的准确率为： 98.03710094909405
# 10000张测试集合中的准确率为： 98.03879310344827
# 10000张测试集合中的准确率为： 98.04048234280792
# 10000张测试集合中的准确率为： 98.04216867469879
# 10000张测试集合中的准确率为： 98.0438521066208
# 10000张测试集合中的准确率为： 98.0455326460481
# 10000张测试集合中的准确率为： 98.04721030042919
# 10000张测试集合中的准确率为： 98.04888507718697
# 10000张测试集合中的准确率为： 98.05055698371893
# 10000张测试集合中的准确率为： 98.05222602739725
# 10000张测试集合中的准确率为： 98.05389221556887
# 10000张测试集合中的准确率为： 98.05555555555556
# 10000张测试集合中的准确率为： 98.05721605465413
# 10000张测试集合中的准确率为： 98.05887372013652
# 10000张测试集合中的准确率为： 98.0392156862745
# 10000张测试集合中的准确率为： 98.04088586030664
# 10000张测试集合中的准确率为： 98.04255319148936
# 10000张测试集合中的准确率为： 98.04421768707483
# 10000张测试集合中的准确率为： 98.04587935429056
# 10000张测试集合中的准确率为： 98.04753820033956
# 10000张测试集合中的准确率为： 98.04919423240034
# 10000张测试集合中的准确率为： 98.05084745762713
# 10000张测试集合中的准确率为： 98.05249788314987
# 10000张测试集合中的准确率为： 98.05414551607446
# 10000张测试集合中的准确率为： 98.05579036348267
# 10000张测试集合中的准确率为： 98.05743243243244
# 10000张测试集合中的准确率为： 98.05907172995781
# 10000张测试集合中的准确率为： 98.03962900505903
# 10000张测试集合中的准确率为： 98.0412805391744
# 10000张测试集合中的准确率为： 98.04292929292929
# 10000张测试集合中的准确率为： 98.04457527333894
# 10000张测试集合中的准确率为： 98.04621848739495
# 10000张测试集合中的准确率为： 98.02686817800168
# 10000张测试集合中的准确率为： 98.02852348993288
# 10000张测试集合中的准确率为： 98.03017602682314
# 10000张测试集合中的准确率为： 98.03182579564489
# 10000张测试集合中的准确率为： 98.03347280334728
# 10000张测试集合中的准确率为： 98.0351170568562
# 10000张测试集合中的准确率为： 98.03675856307436
# 10000张测试集合中的准确率为： 98.03839732888147
# 10000张测试集合中的准确率为： 98.04003336113428
# 10000张测试集合中的准确率为： 98.04166666666667
# 10000张测试集合中的准确率为： 98.04329725228976
# 10000张测试集合中的准确率为： 98.04492512479202
# 10000张测试集合中的准确率为： 98.04655029093932
# 10000张测试集合中的准确率为： 98.04817275747509
# 10000张测试集合中的准确率为： 98.04979253112033
# 10000张测试集合中的准确率为： 98.03067993366501
# 10000张测试集合中的准确率为： 98.03231151615576
# 10000张测试集合中的准确率为： 98.03394039735099
# 10000张测试集合中的准确率为： 98.03556658395368
# 10000张测试集合中的准确率为： 97.99586776859505
# 10000张测试集合中的准确率为： 97.99752270850537
# 10000张测试集合中的准确率为： 97.99917491749174
# 10000张测试集合中的准确率为： 98.00082440230833
# 10000张测试集合中的准确率为： 98.00247116968698
# 10000张测试集合中的准确率为： 98.00411522633745
# 10000张测试集合中的准确率为： 97.98519736842105
# 10000张测试集合中的准确率为： 97.98685291700903
# 10000张测试集合中的准确率为： 97.98850574712644
# 10000张测试集合中的准确率为： 97.96964725184577
# 10000张测试集合中的准确率为： 97.97131147540983
# 10000张测试集合中的准确率为： 97.97297297297297
# 10000张测试集合中的准确率为： 97.97463175122749
# 10000张测试集合中的准确率为： 97.97628781684382
# 10000张测试集合中的准确率为： 97.97794117647058
# 10000张测试集合中的准确率为： 97.9795918367347
# 10000张测试集合中的准确率为： 97.98123980424144
# 10000张测试集合中的准确率为： 97.98288508557457
# 10000张测试集合中的准确率为： 97.98452768729642
# 10000张测试集合中的准确率为： 97.98616761594793
# 10000张测试集合中的准确率为： 97.98780487804878
# 10000张测试集合中的准确率为： 97.98943948009749
# 10000张测试集合中的准确率为： 97.99107142857143
# 10000张测试集合中的准确率为： 97.99270072992701
# 10000张测试集合中的准确率为： 97.99432739059968
# 10000张测试集合中的准确率为： 97.99595141700405
# 10000张测试集合中的准确率为： 97.99757281553399
# 10000张测试集合中的准确率为： 97.99919159256265
# 10000张测试集合中的准确率为： 98.00080775444265
# 10000张测试集合中的准确率为： 98.00242130750605
# 10000张测试集合中的准确率为： 98.00403225806451
# 10000张测试集合中的准确率为： 98.00564061240935
# 10000张测试集合中的准确率为： 98.0072463768116
# 10000张测试集合中的准确率为： 98.00884955752213
# 10000张测试集合中的准确率为： 98.0104501607717
# 10000张测试集合中的准确率为： 98.01204819277109
# 10000张测试集合中的准确率为： 98.01364365971108
# 10000张测试集合中的准确率为： 98.01523656776263
# 10000张测试集合中的准确率为： 98.01682692307693
# 10000张测试集合中的准确率为： 98.01841473178543
# 10000张测试集合中的准确率为： 98.02
# 10000张测试集合中的准确率为： 98.02158273381295
# 10000张测试集合中的准确率为： 98.02316293929712
# 10000张测试集合中的准确率为： 98.02474062250599
# 10000张测试集合中的准确率为： 98.02631578947368
# 10000张测试集合中的准确率为： 98.02788844621514
# 10000张测试集合中的准确率为： 98.02945859872611
# 10000张测试集合中的准确率为： 98.0310262529833
# 10000张测试集合中的准确率为： 98.03259141494436
# 10000张测试集合中的准确率为： 98.03415409054806
# 10000张测试集合中的准确率为： 98.03571428571428
# 10000张测试集合中的准确率为： 98.03727200634417
# 10000张测试集合中的准确率为： 98.03882725832013
# 10000张测试集合中的准确率为： 98.04038004750593
# 10000张测试集合中的准确率为： 98.04193037974683
# 10000张测试集合中的准确率为： 98.04347826086956
# 10000张测试集合中的准确率为： 98.04502369668246
# 10000张测试集合中的准确率为： 98.04656669297553
# 10000张测试集合中的准确率为： 98.0481072555205
# 10000张测试集合中的准确率为： 98.04964539007092
# 10000张测试集合中的准确率为： 98.05118110236221
# 10000张测试集合中的准确率为： 98.05271439811172
# 10000张测试集合中的准确率为： 98.05424528301887
# 10000张测试集合中的准确率为： 98.05577376276511
# 10000张测试集合中的准确率为： 98.05729984301414
# 10000张测试集合中的准确率为： 98.05882352941177
# 10000张测试集合中的准确率为： 98.0603448275862
# 10000张测试集合中的准确率为： 98.06186374314801
# 10000张测试集合中的准确率为： 98.06338028169014
# 10000张测试集合中的准确率为： 98.06489444878812
# 10000张测试集合中的准确率为： 98.06640625
# 10000张测试集合中的准确率为： 98.06791569086651
# 10000张测试集合中的准确率为： 98.06942277691107
# 10000张测试集合中的准确率为： 98.0709275136399
# 10000张测试集合中的准确率为： 98.07242990654206
# 10000张测试集合中的准确率为： 98.07392996108949
# 10000张测试集合中的准确率为： 98.07542768273717
# 10000张测试集合中的准确率为： 98.07692307692307
# 10000张测试集合中的准确率为： 98.07841614906833
# 10000张测试集合中的准确率为： 98.0799069045772
# 10000张测试集合中的准确率为： 98.0813953488372
# 10000张测试集合中的准确率为： 98.08288148721921
# 10000张测试集合中的准确率为： 98.0843653250774
# 10000张测试集合中的准确率为： 98.08584686774941
# 10000张测试集合中的准确率为： 98.08732612055641
# 10000张测试集合中的准确率为： 98.08880308880309
# 10000张测试集合中的准确率为： 98.09027777777779
# 10000张测试集合中的准确率为： 98.0917501927525
# 10000张测试集合中的准确率为： 98.09322033898306
# 10000张测试集合中的准确率为： 98.094688221709
# 10000张测试集合中的准确率为： 98.09615384615384
# 10000张测试集合中的准确率为： 98.09761721752498
# 10000张测试集合中的准确率为： 98.09907834101382
# 10000张测试集合中的准确率为： 98.10053722179586
# 10000张测试集合中的准确率为： 98.10199386503068
# 10000张测试集合中的准确率为： 98.10344827586206
# 10000张测试集合中的准确率为： 98.10490045941806
# 10000张测试集合中的准确率为： 98.10635042081101
# 10000张测试集合中的准确率为： 98.10779816513761
# 10000张测试集合中的准确率为： 98.10924369747899
# 10000张测试集合中的准确率为： 98.11068702290076
# 10000张测试集合中的准确率为： 98.11212814645309
# 10000张测试集合中的准确率为： 98.11356707317073
# 10000张测试集合中的准确率为： 98.11500380807313
# 10000张测试集合中的准确率为： 98.11643835616438
# 10000张测试集合中的准确率为： 98.11787072243347
# 10000张测试集合中的准确率为： 98.1193009118541
# 10000张测试集合中的准确率为： 98.12072892938497
# 10000张测试集合中的准确率为： 98.12215477996965
# 10000张测试集合中的准确率为： 98.12357846853676
# 10000张测试集合中的准确率为： 98.125
# 10000张测试集合中的准确率为： 98.12641937925814
# 10000张测试集合中的准确率为： 98.12783661119516
# 10000张测试集合中的准确率为： 98.12925170068027
# 10000张测试集合中的准确率为： 98.13066465256797
# 10000张测试集合中的准确率为： 98.13207547169812
# 10000张测试集合中的准确率为： 98.13348416289593
# 10000张测试集合中的准确率为： 98.13489073097212
# 10000张测试集合中的准确率为： 98.13629518072288
# 10000张测试集合中的准确率为： 98.13769751693002
# 10000张测试集合中的准确率为： 98.13909774436091
# 10000张测试集合中的准确率为： 98.14049586776859
# 10000张测试集合中的准确率为： 98.1418918918919
# 10000张测试集合中的准确率为： 98.14328582145536
# 10000张测试集合中的准确率为： 98.14467766116941
# 10000张测试集合中的准确率为： 98.14606741573034
# 10000张测试集合中的准确率为： 98.14745508982035
# 10000张测试集合中的准确率为： 98.14884068810771
# 10000张测试集合中的准确率为： 98.15022421524664
# 10000张测试集合中的准确率为： 98.15160567587752
# 10000张测试集合中的准确率为： 98.15298507462687
# 10000张测试集合中的准确率为： 98.15436241610739
# 10000张测试集合中的准确率为： 98.15573770491804
# 10000张测试集合中的准确率为： 98.15711094564408
# 10000张测试集合中的准确率为： 98.15848214285714
# 10000张测试集合中的准确率为： 98.15985130111524
# 10000张测试集合中的准确率为： 98.16121842496285
# 10000张测试集合中的准确率为： 98.16258351893096
# 10000张测试集合中的准确率为： 98.16394658753708
# 10000张测试集合中的准确率为： 98.16530763528539
# 10000张测试集合中的准确率为： 98.16666666666667
# 10000张测试集合中的准确率为： 98.1680236861584
# 10000张测试集合中的准确率为： 98.16937869822485
# 10000张测试集合中的准确率为： 98.17073170731707
# 10000张测试集合中的准确率为： 98.17208271787297
# 10000张测试集合中的准确率为： 98.17343173431735
# 10000张测试集合中的准确率为： 98.17477876106194
# 10000张测试集合中的准确率为： 98.17612380250551
# 10000张测试集合中的准确率为： 98.17746686303387
# ...
# 10000张测试集合中的准确率为： 98.43065693430657
# 10000张测试集合中的准确率为： 98.43142023346303
# 10000张测试集合中的准确率为： 98.43218279047156
# 10000张测试集合中的准确率为： 98.432944606414
# 10000张测试集合中的准确率为： 98.43370568237009
# 10000张测试集合中的准确率为： 98.43446601941747
# 10000张测试集合中的准确率为： 98.43522561863173
# 10000张测试集合中的准确率为： 98.43598448108632
# 10000张测试集合中的准确率为： 98.43674260785265
# 10000张测试集合中的准确率为： 98.4375
# 10000张测试集合中的准确率为： 98.43825665859565
# 10000张测试集合中的准确率为： 98.43901258470474
# 10000张测试集合中的准确率为： 98.43976777939042
# 10000张测试集合中的准确率为： 98.44052224371373
# 10000张测试集合中的准确率为： 98.44127597873369
# 10000张测试集合中的准确率为： 98.44202898550725
# 10000张测试集合中的准确率为： 98.44278126508932
# 10000张测试集合中的准确率为： 98.44353281853282
# 10000张测试集合中的准确率为： 98.44428364688856
# 10000张测试集合中的准确率为： 98.4450337512054
# 10000张测试集合中的准确率为： 98.44578313253012
# 10000张测试集合中的准确率为： 98.4465317919075
# 10000张测试集合中的准确率为： 98.44727973038036
# 10000张测试集合中的准确率为： 98.44802694898941
# 10000张测试集合中的准确率为： 98.44877344877345
# 10000张测试集合中的准确率为： 98.44951923076923
# 10000张测试集合中的准确率为： 98.45026429601154
# 10000张测试集合中的准确率为： 98.42699327569645
# 10000张测试集合中的准确率为： 98.42774843975036
# 10000张测试集合中的准确率为： 98.42850287907869
# 10000张测试集合中的准确率为： 98.42925659472422
# 10000张测试集合中的准确率为： 98.43000958772771
# 10000张测试集合中的准确率为： 98.43076185912794
# 10000张测试集合中的准确率为： 98.4315134099617
# 10000张测试集合中的准确率为： 98.43226424126377
# 10000张测试集合中的准确率为： 98.43301435406698
# 10000张测试集合中的准确率为： 98.4337637494022
# 10000张测试集合中的准确率为： 98.43451242829828
# 10000张测试集合中的准确率为： 98.43526039178214
# 10000张测试集合中的准确率为： 98.4360076408787
# 10000张测试集合中的准确率为： 98.43675417661098
# 10000张测试集合中的准确率为： 98.4375
# 10000张测试集合中的准确率为： 98.43824511206486
# 10000张测试集合中的准确率为： 98.43898951382269
# 10000张测试集合中的准确率为： 98.43973320628871
# 10000张测试集合中的准确率为： 98.44047619047619
# 10000张测试集合中的准确率为： 98.44121846739647
# 10000张测试集合中的准确率为： 98.441960038059
# 10000张测试集合中的准确率为： 98.44270090347123
# 10000张测试集合中的准确率为： 98.44344106463878
# 10000张测试集合中的准确率为： 98.44418052256532
# 10000张测试集合中的准确率为： 98.44491927825261
# 10000张测试集合中的准确率为： 98.44565733270052
# 10000张测试集合中的准确率为： 98.44639468690703
# 10000张测试集合中的准确率为： 98.44713134186819
# 10000张测试集合中的准确率为： 98.44786729857819
# 10000张测试集合中的准确率为： 98.44860255802938
# 10000张测试集合中的准确率为： 98.44933712121212
# 10000张测试集合中的准确率为： 98.450070989115
# 10000张测试集合中的准确率为： 98.4508041627247
# 10000张测试集合中的准确率为： 98.451536643026
# 10000张测试集合中的准确率为： 98.45226843100188
# 10000张测试集合中的准确率为： 98.45299952763344
# 10000张测试集合中的准确率为： 98.45372993389991
# 10000张测试集合中的准确率为： 98.45445965077867
# 10000张测试集合中的准确率为： 98.45518867924528
# 10000张测试集合中的准确率为： 98.45591702027346
# 10000张测试集合中的准确率为： 98.45664467483506
# 10000张测试集合中的准确率为： 98.45737164390013
# 10000张测试集合中的准确率为： 98.45809792843691
# 10000张测试集合中的准确率为： 98.45882352941176
# 10000张测试集合中的准确率为： 98.45954844778927
# 10000张测试集合中的准确率为： 98.4602726845322
# 10000张测试集合中的准确率为： 98.4609962406015
# 10000张测试集合中的准确率为： 98.46171911695632
# 10000张测试集合中的准确率为： 98.462441314554
# 10000张测试集合中的准确率为： 98.46316283435007
# 10000张测试集合中的准确率为： 98.46388367729831
# 10000张测试集合中的准确率为： 98.46460384435069
# 10000张测试集合中的准确率为： 98.46532333645736
# 10000张测试集合中的准确率为： 98.46604215456675
# 10000张测试集合中的准确率为： 98.46676029962546
# 10000张测试集合中的准确率为： 98.46747777257838
# 10000张测试集合中的准确率为： 98.46819457436857
# 10000张测试集合中的准确率为： 98.46891070593735
# 10000张测试集合中的准确率为： 98.4696261682243
# 10000张测试集合中的准确率为： 98.47034096216721
# 10000张测试集合中的准确率为： 98.47105508870216
# 10000张测试集合中的准确率为： 98.47176854876342
# 10000张测试集合中的准确率为： 98.47248134328358
# 10000张测试集合中的准确率为： 98.47319347319348
# 10000张测试集合中的准确率为： 98.47390493942218
# 10000张测试集合中的准确率为： 98.47461574289707
# 10000张测试集合中的准确率为： 98.47532588454376
# 10000张测试集合中的准确率为： 98.47603536528618
# 10000张测试集合中的准确率为： 98.47674418604652
# 10000张测试集合中的准确率为： 98.47745234774523
# 10000张测试集合中的准确率为： 98.47815985130111
# 10000张测试集合中的准确率为： 98.47886669763122
# 10000张测试集合中的准确率为： 98.47957288765087
# 10000张测试集合中的准确率为： 98.48027842227378
# 10000张测试集合中的准确率为： 98.48098330241187
# 10000张测试集合中的准确率为： 98.48168752897543
# 10000张测试集合中的准确率为： 98.48239110287304
# 10000张测试集合中的准确率为： 98.48309402501158
# 10000张测试集合中的准确率为： 98.4837962962963
# 10000张测试集合中的准确率为： 98.48449791763073
# 10000张测试集合中的准确率为： 98.48519888991675
# 10000张测试集合中的准确率为： 98.48589921405456
# 10000张测试集合中的准确率为： 98.4865988909427
# 10000张测试集合中的准确率为： 98.48729792147806
# 10000张测试集合中的准确率为： 98.48799630655586
# 10000张测试集合中的准确率为： 98.48869404706969
# 10000张测试集合中的准确率为： 98.48939114391145
# 10000张测试集合中的准确率为： 98.49008759797142
# 10000张测试集合中的准确率为： 98.49078341013825
# 10000张测试集合中的准确率为： 98.49147858129894
# 10000张测试集合中的准确率为： 98.49217311233886
# 10000张测试集合中的准确率为： 98.49286700414174
# 10000张测试集合中的准确率为： 98.49356025758969
# 10000张测试集合中的准确率为： 98.49425287356321
# 10000张测试集合中的准确率为： 98.49494485294117
# 10000张测试集合中的准确率为： 98.49563619660083
# 10000张测试集合中的准确率为： 98.49632690541782
# 10000张测试集合中的准确率为： 98.49701698026617
# 10000张测试集合中的准确率为： 98.49770642201835
# 10000张测试集合中的准确率为： 98.49839523154516
# 10000张测试集合中的准确率为： 98.49908340971587
# 10000张测试集合中的准确率为： 98.49977095739808
# 10000张测试集合中的准确率为： 98.50045787545788
# 10000张测试集合中的准确率为： 98.50114416475972
# 10000张测试集合中的准确率为： 98.50182982616651
# 10000张测试集合中的准确率为： 98.50251486053955
# 10000张测试集合中的准确率为： 98.50319926873857
# 10000张测试集合中的准确率为： 98.50388305162174
# 10000张测试集合中的准确率为： 98.50456621004567
# 10000张测试集合中的准确率为： 98.50524874486536
# 10000张测试集合中的准确率为： 98.50593065693431
# 10000张测试集合中的准确率为： 98.50661194710443
# 10000张测试集合中的准确率为： 98.50729261622607
# 10000张测试集合中的准确率为： 98.50797266514807
# 10000张测试集合中的准确率为： 98.50865209471766
# 10000张测试集合中的准确率为： 98.50933090578062
# 10000张测试集合中的准确率为： 98.51000909918108
# 10000张测试集合中的准确率为： 98.5106866757617
# 10000张测试集合中的准确率为： 98.51136363636364
# 10000张测试集合中的准确率为： 98.51203998182643
# 10000张测试集合中的准确率为： 98.5127157129882
# 10000张测试集合中的准确率为： 98.51339083068544
# 10000张测试集合中的准确率为： 98.51406533575317
# 10000张测试集合中的准确率为： 98.51473922902494
# 10000张测试集合中的准确率为： 98.51541251133273
# 10000张测试集合中的准确率为： 98.51608518350702
# 10000张测试集合中的准确率为： 98.51675724637681
# 10000张测试集合中的准确率为： 98.51742870076959
# 10000张测试集合中的准确率为： 98.51809954751131
# 10000张测试集合中的准确率为： 98.5187697874265
# 10000张测试集合中的准确率为： 98.51943942133815
# 10000张测试集合中的准确率为： 98.52010845006778
# 10000张测试集合中的准确率为： 98.52077687443541
# 10000张测试集合中的准确率为： 98.5214446952596
# 10000张测试集合中的准确率为： 98.5221119133574
# 10000张测试集合中的准确率为： 98.52277852954442
# 10000张测试集合中的准确率为： 98.52344454463481
# 10000张测试集合中的准确率为： 98.52410995944119
# 10000张测试集合中的准确率为： 98.52477477477477
# 10000张测试集合中的准确率为： 98.52543899144528
# 10000张测试集合中的准确率为： 98.52610261026102
# 10000张测试集合中的准确率为： 98.52676563202878
# 10000张测试集合中的准确率为： 98.52742805755396
# 10000张测试集合中的准确率为： 98.52808988764045
# 10000张测试集合中的准确率为： 98.52875112309074
# 10000张测试集合中的准确率为： 98.52941176470588
# 10000张测试集合中的准确率为： 98.53007181328546
# 10000张测试集合中的准确率为： 98.53073126962764
# 10000张测试集合中的准确率为： 98.53139013452915
# 10000张测试集合中的准确率为： 98.5320484087853
# 10000张测试集合中的准确率为： 98.53270609318996
# 10000张测试集合中的准确率为： 98.5333631885356
# 10000张测试集合中的准确率为： 98.53401969561325
# 10000张测试集合中的准确率为： 98.53467561521254
# 10000张测试集合中的准确率为： 98.53533094812164
# 10000张测试集合中的准确率为： 98.53598569512741
# 10000张测试集合中的准确率为： 98.53663985701519
# 10000张测试集合中的准确率为： 98.53729343456901
# 10000张测试集合中的准确率为： 98.53794642857143
# 10000张测试集合中的准确率为： 98.53859883980365
# 10000张测试集合中的准确率为： 98.5392506690455
# 10000张测试集合中的准确率为： 98.53990191707534
# 10000张测试集合中的准确率为： 98.54055258467022
# 10000张测试集合中的准确率为： 98.54120267260579
# 10000张测试集合中的准确率为： 98.54185218165628
# 10000张测试集合中的准确率为： 98.54250111259458
# 10000张测试集合中的准确率为： 98.54314946619218
# 10000张测试集合中的准确率为： 98.54379724321922
# 10000张测试集合中的准确率为： 98.54444444444445
# 10000张测试集合中的准确率为： 98.54509107063527
# 10000张测试集合中的准确率为： 98.54573712255772
# 10000张测试集合中的准确率为： 98.5352862849534
# 10000张测试集合中的准确率为： 98.5248447204969
# 10000张测试集合中的准确率为： 98.51441241685144
# 10000张测试集合中的准确率为： 98.51507092198581
# 10000张测试集合中的准确率为： 98.50465219317678
# 10000张测试集合中的准确率为： 98.50531443755536
# 10000张测试集合中的准确率为： 98.50597609561753
# 10000张测试集合中的准确率为： 98.49557522123894
# 10000张测试集合中的准确率为： 98.49624060150376
# 10000张测试集合中的准确率为： 98.49690539345711
# 10000张测试集合中的准确率为： 98.49756959787892
# 10000张测试集合中的准确率为： 98.4982332155477
# 10000张测试集合中的准确率为： 98.49889624724062
# 10000张测试集合中的准确率为： 98.49955869373345
# 10000张测试集合中的准确率为： 98.50022055580062
# 10000张测试集合中的准确率为： 98.50088183421516
# 10000张测试集合中的准确率为： 98.50154252974879
# 10000张测试集合中的准确率为： 98.50220264317181
# 10000张测试集合中的准确率为： 98.5028621752532
# 10000张测试集合中的准确率为： 98.50352112676056
# 10000张测试集合中的准确率为： 98.50417949846019
# 10000张测试集合中的准确率为： 98.50483729111697
# 10000张测试集合中的准确率为： 98.50549450549451
# 10000张测试集合中的准确率为： 98.50615114235501
# 10000张测试集合中的准确率为： 98.50680720245938
# 10000张测试集合中的准确率为： 98.50746268656717
# 10000张测试集合中的准确率为： 98.5081175954366
# 10000张测试集合中的准确率为： 98.50877192982456
# 10000张测试集合中的准确率为： 98.50942569048662
# 10000张测试集合中的准确率为： 98.51007887817704
# 10000张测试集合中的准确率为： 98.5107314936487
# 10000张测试集合中的准确率为： 98.51138353765324
# 10000张测试集合中的准确率为： 98.51203501094092
# 10000张测试集合中的准确率为： 98.51268591426073
# 10000张测试集合中的准确率为： 98.51333624836029
# 10000张测试集合中的准确率为： 98.51398601398601
# 10000张测试集合中的准确率为： 98.51463521188292
# 10000张测试集合中的准确率为： 98.51528384279476
# 10000张测试集合中的准确率为： 98.515931907464
# 10000张测试集合中的准确率为： 98.51657940663176
# 10000张测试集合中的准确率为： 98.51722634103794
# 10000张测试集合中的准确率为： 98.51787271142109
# 10000张测试集合中的准确率为： 98.51851851851852
# 10000张测试集合中的准确率为： 98.5191637630662
# 10000张测试集合中的准确率为： 98.51980844579887
# 10000张测试集合中的准确率为： 98.52045256744995
# 10000张测试集合中的准确率为： 98.52109612875162
# 10000张测试集合中的准确率为： 98.52173913043478
# 10000张测试集合中的准确率为： 98.52238157322904
# 10000张测试集合中的准确率为： 98.52302345786272
# 10000张测试集合中的准确率为： 98.52366478506296
# 10000张测试集合中的准确率为： 98.52430555555556
# 10000张测试集合中的准确率为： 98.52494577006507
# 10000张测试集合中的准确率为： 98.52558542931483
# 10000张测试集合中的准确率为： 98.52622453402688
# 10000张测试集合中的准确率为： 98.52686308492201
# 10000张测试集合中的准确率为： 98.5275010827198
# 10000张测试集合中的准确率为： 98.52813852813853
# 10000张测试集合中的准确率为： 98.52877542189529
# 10000张测试集合中的准确率为： 98.52941176470588
# 10000张测试集合中的准确率为： 98.53004755728492
# 10000张测试集合中的准确率为： 98.53068280034573
# 10000张测试集合中的准确率为： 98.53131749460043
# 10000张测试集合中的准确率为： 98.53195164075993
# 10000张测试集合中的准确率为： 98.53258523953387
# 10000张测试集合中的准确率为： 98.53321829163072
# 10000张测试集合中的准确率为： 98.53385079775765
# 10000张测试集合中的准确率为： 98.53448275862068
# 10000张测试集合中的准确率为： 98.5351141749246
# 10000张测试集合中的准确率为： 98.53574504737296
# 10000张测试集合中的准确率为： 98.5363753766681
# 10000张测试集合中的准确率为： 98.53700516351118
# 10000张测试集合中的准确率为： 98.53763440860214
# 10000张测试集合中的准确率为： 98.53826311263973
# 10000张测试集合中的准确率为： 98.53889127632144
# 10000张测试集合中的准确率为： 98.53951890034365
# 10000张测试集合中的准确率为： 98.54014598540147
# 10000张测试集合中的准确率为： 98.54077253218884
# 10000张测试集合中的准确率为： 98.54139854139854
# 10000张测试集合中的准确率为： 98.54202401372213
# 10000张测试集合中的准确率为： 98.54264894984998
# 10000张测试集合中的准确率为： 98.5432733504713
# 10000张测试集合中的准确率为： 98.54389721627409
# 10000张测试集合中的准确率为： 98.5445205479452
# 10000张测试集合中的准确率为： 98.5451433461703
# 10000张测试集合中的准确率为： 98.54576561163387
# 10000张测试集合中的准确率为： 98.54638734501924
# 10000张测试集合中的准确率为： 98.54700854700855
# 10000张测试集合中的准确率为： 98.54762921828278
# 10000张测试集合中的准确率为： 98.54824935952178
# 10000张测试集合中的准确率为： 98.54886897140418
# 10000张测试集合中的准确率为： 98.54948805460751
# 10000张测试集合中的准确率为： 98.5501066098081
# 10000张测试集合中的准确率为： 98.55072463768117
# 10000张测试集合中的准确率为： 98.55134213890072
# 10000张测试集合中的准确率为： 98.55195911413969
# 10000张测试集合中的准确率为： 98.55257556406983
# 10000张测试集合中的准确率为： 98.55319148936171
# 10000张测试集合中的准确率为： 98.55380689068481
# 10000张测试集合中的准确率为： 98.55442176870748
# 10000张测试集合中的准确率为： 98.5550361240969
# 10000张测试集合中的准确率为： 98.55564995751912
# 10000张测试集合中的准确率为： 98.55626326963906
# 10000张测试集合中的准确率为： 98.55687606112055
# 10000张测试集合中的准确率为： 98.55748833262622
# 10000张测试集合中的准确率为： 98.55810008481765
# 10000张测试集合中的准确率为： 98.55871131835524
# 10000张测试集合中的准确率为： 98.5593220338983
# 10000张测试集合中的准确率为： 98.55993223210504
# 10000张测试集合中的准确率为： 98.56054191363252
# 10000张测试集合中的准确率为： 98.56115107913669
# 10000张测试集合中的准确率为： 98.56175972927242
# 10000张测试集合中的准确率为： 98.56236786469344
# 10000张测试集合中的准确率为： 98.56297548605241
# 10000张测试集合中的准确率为： 98.56358259400085
# 10000张测试集合中的准确率为： 98.5641891891892
# 10000张测试集合中的准确率为： 98.56479527226678
# 10000张测试集合中的准确率为： 98.56540084388186
# 10000张测试集合中的准确率为： 98.56600590468156
# 10000张测试集合中的准确率为： 98.56661045531197
# 10000张测试集合中的准确率为： 98.56721449641803
# 10000张测试集合中的准确率为： 98.56781802864364
# 10000张测试集合中的准确率为： 98.56842105263158
# 10000张测试集合中的准确率为： 98.56902356902357
# 10000张测试集合中的准确率为： 98.56962557846025
# 10000张测试集合中的准确率为： 98.57022708158117
# 10000张测试集合中的准确率为： 98.57082807902479
# 10000张测试集合中的准确率为： 98.57142857142858
# 10000张测试集合中的准确率为： 98.57202855942882
# 10000张测试集合中的准确率为： 98.5726280436608
# 10000张测试集合中的准确率为： 98.56273604699958
# 10000张测试集合中的准确率为： 98.5633389261745
# 10000张测试集合中的准确率为： 98.56394129979036
# 10000张测试集合中的准确率为： 98.56454316848283
# 10000张测试集合中的准确率为： 98.56514453288648
# 10000张测试集合中的准确率为： 98.56574539363484
# 10000张测试集合中的准确率为： 98.5663457513604
# 10000张测试集合中的准确率为： 98.56694560669456
# 10000张测试集合中的准确率为： 98.56754496026767
# 10000张测试集合中的准确率为： 98.56814381270902
# 10000张测试集合中的准确率为： 98.56874216464688
# 10000张测试集合中的准确率为： 98.56934001670844
# 10000张测试集合中的准确率为： 98.56993736951983
# 10000张测试集合中的准确率为： 98.57053422370618
# 10000张测试集合中的准确率为： 98.57113057989153
# 10000张测试集合中的准确率为： 98.57172643869892
# 10000张测试集合中的准确率为： 98.57232180075032
# 10000张测试集合中的准确率为： 98.57291666666667
# 10000张测试集合中的准确率为： 98.57351103706789
# 10000张测试集合中的准确率为： 98.57410491257286
# 10000张测试集合中的准确率为： 98.57469829379941
# 10000张测试集合中的准确率为： 98.57529118136439
# 10000张测试集合中的准确率为： 98.57588357588357
# 10000张测试集合中的准确率为： 98.57647547797174
# 10000张测试集合中的准确率为： 98.57706688824263
# 10000张测试集合中的准确率为： 98.57765780730897
# 10000张测试集合中的准确率为： 98.56787048567871
# 10000张测试集合中的准确率为： 98.56846473029046
# 10000张测试集合中的准确率为： 98.5586893405226
# 10000张测试集合中的准确率为： 98.55928689883913
# 10000张测试集合中的准确率为： 98.55988396187318
# 10000张测试集合中的准确率为： 98.56048053024027
# 10000张测试集合中的准确率为： 98.56107660455487
# 10000张测试集合中的准确率为： 98.56167218543047
# 10000张测试集合中的准确率为： 98.56226727347952
# 10000张测试集合中的准确率为： 98.56286186931348
# 10000张测试集合中的准确率为： 98.55312112443158
# 10000张测试集合中的准确率为： 98.53305785123968
# 10000张测试集合中的准确率为： 98.53366377529946
# 10000张测试集合中的准确率为： 98.53426919900909
# 10000张测试集合中的准确率为： 98.53487412298804
# 10000张测试集合中的准确率为： 98.52516501650165
# 10000张测试集合中的准确率为： 98.52577319587628
# 10000张测试集合中的准确率为： 98.51607584501237
# 10000张测试集合中的准确率为： 98.51668726823239
# 10000张测试集合中的准确率为： 98.5172981878089
# 10000张测试集合中的准确率为： 98.51790860436394
# 10000张测试集合中的准确率为： 98.51851851851852
# 10000张测试集合中的准确率为： 98.51912793089264
# 10000张测试集合中的准确率为： 98.51973684210526
# 10000张测试集合中的准确率为： 98.51006987258528
# 10000张测试集合中的准确率为： 98.50041084634347
# 10000张测试集合中的准确率为： 98.50102669404518
# 10000张测试集合中的准确率为： 98.50164203612479
# 10000张测试集合中的准确率为： 98.50225687320476
# 10000张测试集合中的准确率为： 98.50287120590649
# 10000张测试集合中的准确率为： 98.50348503485034
# 10000张测试集合中的准确率为： 98.50409836065573
# 10000张测试集合中的准确率为： 98.50471118394101
# 10000张测试集合中的准确率为： 98.5053235053235
# 10000张测试集合中的准确率为： 98.49570200573066
# 10000张测试集合中的准确率为： 98.49631751227496
# 10000张测试集合中的准确率为： 98.49693251533742
# 10000张测试集合中的准确率为： 98.48732624693378
# 10000张测试集合中的准确率为： 98.4879444217409
# 10000张测试集合中的准确率为： 98.48856209150327
# 10000张测试集合中的准确率为： 98.48917925683952
# 10000张测试集合中的准确率为： 98.48979591836735
# 10000张测试集合中的准确率为： 98.49041207670338
# 10000张测试集合中的准确率为： 98.4910277324633
# 10000张测试集合中的准确率为： 98.49164288626172
# 10000张测试集合中的准确率为： 98.49225753871231
# 10000张测试集合中的准确率为： 98.49287169042769
# 10000张测试集合中的准确率为： 98.49348534201955
# 10000张测试集合中的准确率为： 98.4940984940985
# 10000张测试集合中的准确率为： 98.4947111472742
# 10000张测试集合中的准确率为： 98.49532330215534
# 10000张测试集合中的准确率为： 98.4959349593496
# 10000张测试集合中的准确率为： 98.49654611946363
# 10000张测试集合中的准确率为： 98.49715678310316
# 10000张测试集合中的准确率为： 98.49776695087293
# 10000张测试集合中的准确率为： 98.49837662337663
# 10000张测试集合中的准确率为： 98.49898580121705
# 10000张测试集合中的准确率为： 98.49959448499594
# 10000张测试集合中的准确率为： 98.50020267531414
# 10000张测试集合中的准确率为： 98.50081037277147
# 10000张测试集合中的准确率为： 98.50141757796679
# 10000张测试集合中的准确率为： 98.50202429149797
# 10000张测试集合中的准确率为： 98.50263051396196
# 10000张测试集合中的准确率为： 98.5032362459547
# 10000张测试集合中的准确率为： 98.50384148807116
# 10000张测试集合中的准确率为： 98.50444624090542
# 10000张测试集合中的准确率为： 98.5050505050505
# 10000张测试集合中的准确率为： 98.50565428109854
# 10000张测试集合中的准确率为： 98.5062575696407
# 10000张测试集合中的准确率为： 98.50686037126715
# 10000张测试集合中的准确率为： 98.50746268656717
# 10000张测试集合中的准确率为： 98.50806451612904
# 10000张测试集合中的准确率为： 98.5086658605401
# 10000张测试集合中的准确率为： 98.50926672038679
# 10000张测试集合中的准确率为： 98.50986709625454
# 10000张测试集合中的准确率为： 98.51046698872786
# 10000张测试集合中的准确率为： 98.51106639839034
# 10000张测试集合中的准确率为： 98.51166532582461
# 10000张测试集合中的准确率为： 98.51226377161238
# 10000张测试集合中的准确率为： 98.5128617363344
# 10000张测试集合中的准确率为： 98.51345922057051
# 10000张测试集合中的准确率为： 98.51405622489959
# 10000张测试集合中的准确率为： 98.51465274989964
# 10000张测试集合中的准确率为： 98.51524879614767
# 10000张测试集合中的准确率为： 98.51584436421982
# 10000张测试集合中的准确率为： 98.51643945469127
# 10000张测试集合中的准确率为： 98.51703406813628
# 10000张测试集合中的准确率为： 98.5176282051282
# 10000张测试集合中的准确率为： 98.51822186623949
# 10000张测试集合中的准确率为： 98.51881505204163
# 10000张测试集合中的准确率为： 98.51940776310524
# 10000张测试集合中的准确率为： 98.52
# tensor(9852)
